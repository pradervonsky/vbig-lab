# %% [markdown]
# <a href="https://colab.research.google.com/github/pradervonsky/vbig-lab/blob/main/evaluation/iaa-test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inter-Annotator Agreement (IAA)
#
# Pipeline:
# 1. Pull `human_insights` rows from Supabase
# 2. Build units, parsing the dashboard-chart-level LoD
# 3. Compute BERTScore-based pairwise distances for all 3 annotator pairs
# 4. Compute Krippendorff's α overall, per level, and per dashboard
# 5. Compute ROUGE, BLEU, METEOR

# %% [markdown]
# ## Dependencies

# %%
# !pip install -q bert-score supabase pandas numpy openpyxl rouge_score

# %% [markdown]
# ## STEP 1: Pull data from Supabase

# %%
import pandas as pd
import numpy as np
import re
from bert_score import score as bert_score
from supabase import create_client
from itertools import combinations
from google.colab import userdata

SUPABASE_URL = userdata.get("SUPABASE_URL")
SUPABASE_KEY = userdata.get("SUPABASE_KEY")

supabase = create_client(SUPABASE_URL, SUPABASE_KEY)
response = supabase.table("human_insights").select("*").execute()
df_raw = pd.DataFrame(response.data)

print("irr_flag unique values:", df_raw["irr_flag"].unique())
irr_df = df_raw[df_raw["irr_flag"] == True].reset_index(drop=True)
print(f"IRR rows: {len(irr_df)}")
# Out:
# irr_flag unique values: [False  True]
# IRR rows: 10

# %% [markdown]
# ## STEP 2: Parsing step

# %%
NA_PATTERN = re.compile(r"^(not applicable|n/a)$", re.IGNORECASE)

def is_missing(text):
    if text is None:
        return True
    # Strip whitespace and trailing punctuation before matching
    cleaned = str(text).strip().rstrip(".")
    cleaned = cleaned.strip()  # strip again after removing dot
    return cleaned.lower() in {"not applicable", "n/a", ""}

def normalize_value(val):
    if val is None:
        return None
    cleaned = str(val).strip().rstrip(".").strip()
    if cleaned == "" or NA_PATTERN.match(cleaned):
        return None
    return cleaned

def parse_charts(text):
    charts = []
    if not text or (isinstance(text, float) and np.isnan(text)):
        return charts

    blocks = re.split(r"(?=Chart\s+\d+\s*[:.])", text.strip())
    for block in blocks:
        block = block.strip()
        if not block:
            continue
        lines = block.splitlines()
        header = lines[0].strip()
        match = re.match(r"Chart\s+(\d+)\s*[:.]\s*(.*)", header)
        if not match:
            continue
        chart_id = int(match.group(1))
        title    = match.group(2).strip()

        L2 = L3 = L4 = None
        for line in lines[1:]:
            line = line.strip()
            if line.startswith("L2:"):
                L2 = normalize_value(line[3:].strip())
            elif line.startswith("L3:"):
                L3 = normalize_value(line[3:].strip())
            elif line.startswith("L4:"):
                L4 = normalize_value(line[3:].strip())

        charts.append({
            "chart_id": chart_id,
            "title":    title,
            "L2":       L2,
            "L3":       L3,
            "L4":       L4,
        })
    return charts

# %%
ANNOTATOR_COLS = ["insight_part_1", "insight_part_2", "insight_part_3"]

records = []
for _, row in irr_df.iterrows():
    row_id      = row["id"]
    metadata_id = row["metadata_id"]

    # Parse each annotator's blob
    parsed = {col: {c["chart_id"]: c for c in parse_charts(row[col])}
              for col in ANNOTATOR_COLS}

    # All chart_ids seen across any annotator
    all_chart_ids = sorted(
        set().union(*[set(p.keys()) for p in parsed.values()])
    )

    for chart_id in all_chart_ids:
        # Get title from whichever annotator has this chart
        title = next(
            (parsed[col][chart_id]["title"]
             for col in ANNOTATOR_COLS
             if chart_id in parsed[col]),
            ""
        )
        for level in ["L2", "L3", "L4"]:
            records.append({
                "row_id":      row_id,
                "metadata_id": metadata_id,
                "chart_id":    chart_id,
                "title":       title,
                "level":       level,
                "unit_id":     f"{row_id}__chart{chart_id}__{level}",
                "annotator_1": parsed["insight_part_1"].get(chart_id, {}).get(level),
                "annotator_2": parsed["insight_part_2"].get(chart_id, {}).get(level),
                "annotator_3": parsed["insight_part_3"].get(chart_id, {}).get(level),
            })

long_df = pd.DataFrame(records)
print(f"\nTotal units: {len(long_df)}")
print(long_df.head(12).to_string())
# Out:
# Total units: 147
#                                   row_id                           metadata_id  chart_id                        title level                                           unit_id                                                                                                                                                                                                                                                                                             annotator_1                                                                                                                                                                                                                                                                                                              annotator_2                                                                                                                                                                                                                                                                                                                                                                         annotator_3
# 0   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         1          Scoreboard Overview    L2  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart1__L2                                                                                                                                                                                                From 793 customers and total orders of 5,009, resulting in total sales of $2,297,201 and $286,397 profit                                                                                                                                                                                                        Total customers are 793, total orders are 5,009, total nominal of sales is $2,297,201, and the profit is $286,397                                                                                                                                                                                                                                                                                             Customer count is 793, total orders is 5,009, Sales is 2,297,201 and  Profit is 286,397
# 1   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         1          Scoreboard Overview    L3  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart1__L3                                                                                                                                                                                                                                                                                                    None                                                                                                                                                                                                                                                                                                                     None                                                                                                                                             The business records 793 customers and 5,009 total orders, while generating 2,297,201 in sales and 286,397 in profit, showing substantially higher order volume than customer count alongside strong revenue and positive profitability
# 2   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         1          Scoreboard Overview    L4  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart1__L4                                                                                                                                                                                            An average of 6 orders per customer, suggesting repeated orders by loyal customers, resulting in high profit                                                      The combination of a large customer base, a high order count, and strong total sales suggests the business operates at substantial scale, while the level of profit indicates that this scale is also translating into meaningful earnings rather than volume alone                                      The combination of 5,009 orders from 793 customers and 286,397 profit on 2.30M in sales suggests the business may be generating revenue through strong repeat purchasing rather than customer count alone, which could indicate a reasonably engaged customer base and solid monetization efficiency if that order activity is being sustained
# 3   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         2               Sales by State    L2  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart2__L2                                                                                                                                                                                                                 The highest sales by state are in the West area at $725K, followed by the East at $679K                                                                                                                                                                                                                                         West State's Sales is $725K, Central is $501K, South is $392K, and East is $679K                                                                                                                                                                                                                                                                                Sales of West are 725K, East 679K, Central 501K, and South 392K. West is highest and South is lowest
# 4   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         2               Sales by State    L3  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart2__L3  Monthly trend sales between January 2016 and 2020 show that West and East have the same pattern each year, with the end of the year having higher sales than the rest, while Central and South have no pattern, especially in South, where the highest sales peak at around the first semester of 2016                                                                                             Sales appear concentrated in the coastal regions, with the West standing slightly ahead of the East, while Central and South sit noticeably lower and the state-level distribution across the interior looks lighter overall                                                                                                                      Overall sales are concentrated in the West (725K) and East (679K), with California standing out as the largest state contributor, while Central (501K) and especially South (392K) lag behind despite all regions showing fluctuating sales patterns over time
# 5   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         2               Sales by State    L4  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart2__L4                                                                                                         This suggests the need for different sales strategies and promotions in the Central and South areas than in the West and East to push at least the same trend and keep up the sales performance                                                       This coastal concentration may indicate that the business performs strongest in denser and more commercially developed markets, suggesting that the West and East provide the core sales base while inland and southern areas remain comparatively less penetrated  Sales are concentrated in the West and East, with the West leading overall, which may indicate the business performs strongest in larger and more commercially active coastal markets, while the differing regional trend patterns could show uneven market maturity, customer density, or sales execution across regions rather than a uniformly distributed national demand base
# 6   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         3   West Sales by Sub-Category    L2  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart3__L2                                                                                                                                                                                                            The highest sales are in the Chairs sub-category at $101.8K, and the lowest are in Fasteners                                                                                                                                                                                                                 Sub-Category with the highest sale in the West is Chairs by $101.8K and the lowest is Fasteners by $0.9K                                                                                                                                                                                                                                                                                               Chairs Sales is the highest in West with 101.8K and fasteners is the lowest with 0.9K
# 7   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         3   West Sales by Sub-Category    L3  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart3__L3                                                                                                                                                                                                                                                                                                    None                                                                                                            Sales across West sub-categories are highly uneven, with a few leading categories such as Chairs, Phones, and Tables standing clearly above the rest, while the lower-ranked items taper off into a long tail                                                                                              West sales are concentrated in a few leading sub-categories, with Chairs (101.8K) and Phones just behind as the top contributors, followed by Tables (84.8K) and Storage (70.5K), while smaller sub categories such as Art, Labels, Envelopes and Fasteners contribute only marginally
# 8   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         3   West Sales by Sub-Category    L4  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart3__L4                                                                                                                    This ranked sub-category by sales, suggesting the items with a higher price unit surpassed the ones that rely on sales from quantity, like paper, supplies, envelopes, and fasteners                                                    This pattern suggests that sales in the West are driven disproportionately by a small set of sub-categories, indicating where customer demand is strongest and where assortment, stocking, and promotional focus may have the greatest impact on regional performance                                                                                                     West sales concentration in Chairs, Phones, Tables, and Storage suggests the region may be driven by a mix of workspace setup and productivity-related demand, which could indicate stronger commercial traction in practical office items categories than in smaller accessory
# 9   f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         4  Top 10 Products in the West    L2  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart4__L2                                                                                                                                                                                         Canon ImageCLASS 2200 advanced copier, with sales of $14.0K, sits in first place as the top product in the west                                                                                                                                                                                                                            Product with the highest sales in the West is Canon imageCLASS 2200 Advanced Copier by $14.0K                                                                                                                                                                                                                                                                                                 Canon imageCLASS 2200 Advanced Copier, with sales of 14.0K , outsold other products
# 10  f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         4  Top 10 Products in the West    L3  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart4__L3                                                                                                                                                                                                                                                                                                    None                                                                                                                                                                  The gap between the top two products and the rest is noticeably wider, suggesting a clear split between a small leading tier and the remaining products                                                                                                                       Product sales in the West are led by a small top tier, with the Canon imageCLASS 2200 Advanced Copier (14.0K) and the High Speed Automatic Electric Letter Opener (13.1K) ahead, while the remaining top products cluster tightly in the roughly 6K–10K range
# 11  f451d481-b828-40ed-a9a4-fc7fd6d6caf2  3de1a247-98df-43a9-966d-af74b2354dde         4  Top 10 Products in the West    L4  f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart4__L4                                                                       Canon ImageCLASS 2200 advanced copier outperforms other listed products, suggesting strong market fit and indicating the business could benefit from prioritizing stock availability and marketing this product to sustain demand  This pattern may indicate that, beyond the two standout products, the products ranked three to ten still form a strong secondary tier, suggesting a valuable opportunity to widen the next sales period’s growth base by promoting these products more actively rather than relying too heavily on only the top leaders                                              The copiers, office furniture, and business equipment among the top selling products in the West suggests regional demand may be affected by workplace and business purchasing needs rather than mainly by casual consumer items, which could reflect a customer base with stronger demand for functional, higher utility office items

# %%
print("\nNOT APPLICABLE counts per level per annotator:")
for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level]
    print(f"  {level}: "
          f"ann1={sub['annotator_1'].isna().sum()} | "
          f"ann2={sub['annotator_2'].isna().sum()} | "
          f"ann3={sub['annotator_3'].isna().sum()} | "
          f"total_units={len(sub)}")
# Out:
# NOT APPLICABLE counts per level per annotator:
#   L2: ann1=0 | ann2=0 | ann3=0 | total_units=49
#   L3: ann1=25 | ann2=4 | ann3=2 | total_units=49
#   L4: ann1=0 | ann2=0 | ann3=0 | total_units=49

# %%
# Check chart count per dashboard per annotator
print("=== Chart count per dashboard per annotator ===\n")

for row_id in sorted(long_df["row_id"].unique()):
    sub = long_df[long_df["row_id"] == row_id]

    # Get unique charts seen per annotator
    ann1_charts = sub[sub["annotator_1"].notna()]["chart_id"].unique()
    ann2_charts = sub[sub["annotator_2"].notna()]["chart_id"].unique()
    ann3_charts = sub[sub["annotator_3"].notna()]["chart_id"].unique()

    total_charts = sub["chart_id"].nunique()
    metadata_id = sub["metadata_id"].iloc[0]

    print(f"Dashboard: {row_id[:8]}… (metadata: {metadata_id[:8]}…)")
    print(f"  Total charts parsed: {total_charts}")
    print(f"  ann1 charts with content: {sorted(ann1_charts)} ({len(ann1_charts)})")
    print(f"  ann2 charts with content: {sorted(ann2_charts)} ({len(ann2_charts)})")
    print(f"  ann3 charts with content: {sorted(ann3_charts)} ({len(ann3_charts)})")

    # Flag mismatches
    all_charts = set(sub["chart_id"].unique())
    for ann_label, ann_charts in [("ann1", ann1_charts), ("ann2", ann2_charts), ("ann3", ann3_charts)]:
        missing = all_charts - set(ann_charts)
        if missing:
            print(f"  ⚠️  {ann_label} missing charts: {sorted(missing)}")
    print()
# Out:
# === Chart count per dashboard per annotator ===
#
# Dashboard: 08006d53… (metadata: 27052e58…)
#   Total charts parsed: 4
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#
# Dashboard: 1120a289… (metadata: 4f4b551b…)
#   Total charts parsed: 5
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)] (5)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)] (5)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)] (5)
#
# Dashboard: 2e5b2881… (metadata: 932c11c0…)
#   Total charts parsed: 6
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)] (6)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)] (6)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)] (6)
#
# Dashboard: 511bca34… (metadata: 14b81d7e…)
#   Total charts parsed: 3
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3)] (3)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3)] (3)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3)] (3)
#
# Dashboard: 723340b5… (metadata: 3a2d6971…)
#   Total charts parsed: 4
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#
# Dashboard: b164ac02… (metadata: 8040a121…)
#   Total charts parsed: 6
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)] (6)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)] (6)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)] (6)
#
# Dashboard: cfe29540… (metadata: abee2e83…)
#   Total charts parsed: 7
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7)] (7)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7)] (7)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7)] (7)
#
# Dashboard: dc09d834… (metadata: a3e6d04a…)
#   Total charts parsed: 6
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)] (6)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)] (6)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)] (6)
#
# Dashboard: e743f36f… (metadata: d6292274…)
#   Total charts parsed: 4
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#
# Dashboard: f451d481… (metadata: 3de1a247…)
#   Total charts parsed: 4
#   ann1 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#   ann2 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)
#   ann3 charts with content: [np.int64(1), np.int64(2), np.int64(3), np.int64(4)] (4)

# %% [markdown]
# ## STEP 3: BERTScore-based distance function
#
# `distance(a, b) = 1 - BERTScore_F1(a, b)`
# `NOT APPLICABLE` entries are treated as missing (`np.nan`).

# %%
import torch
import numpy as np
from bert_score import score as bert_score
from itertools import combinations

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
MODEL_TYPE = "roberta-large"
print(f"Using device: {DEVICE}, model: {MODEL_TYPE}")

ANNOTATOR_COLS = ["annotator_1", "annotator_2", "annotator_3"]
ANNOTATOR_PAIRS = list(combinations(ANNOTATOR_COLS, 2))

def is_missing(text):
    if text is None:
        return True
    return str(text).strip().lower() in {"not applicable", "n/a", ""}

def bertscore_distance_batch(refs, hyps, model_type=MODEL_TYPE, device=DEVICE):
    """
    Compute BERTScore F1 for parallel lists of refs and hyps.
    Returns a numpy array of distances (1 - F1).
    Missing values return np.nan.
    """
    assert len(refs) == len(hyps)
    distances = np.full(len(refs), np.nan)

    valid_indices = [
        i for i, (r, h) in enumerate(zip(refs, hyps))
        if not is_missing(r) and not is_missing(h)
    ]

    if not valid_indices:
        return distances

    valid_refs = [str(refs[i]) for i in valid_indices]
    valid_hyps = [str(hyps[i]) for i in valid_indices]

    _, _, F1 = bert_score(
        valid_hyps, valid_refs,
        model_type=model_type,
        device=device,
        verbose=False
    )

    for idx, f1_val in zip(valid_indices, F1.numpy()):
        distances[idx] = 1.0 - f1_val

    return distances

# ============================================================
# Compute pairwise distances on long_df
# ============================================================
DIST_COLS = []
for (col_a, col_b) in ANNOTATOR_PAIRS:
    suffix_a = col_a.split("_")[-1]
    suffix_b = col_b.split("_")[-1]
    pair_key = f"dist_{suffix_a}{suffix_b}"
    DIST_COLS.append(pair_key)
    print(f"Computing {pair_key} ({col_a} vs {col_b}) ...")
    long_df[pair_key] = bertscore_distance_batch(
        long_df[col_a].tolist(),
        long_df[col_b].tolist(),
    )

print("\nSample distances:")
print(long_df[["unit_id", "chart_id", "level"] + DIST_COLS].head(12).to_string(index=False))
# Out:
# Using device: cuda, model: roberta-large
# Computing dist_12 (annotator_1 vs annotator_2) ...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Computing dist_13 (annotator_1 vs annotator_3) ...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Computing dist_23 (annotator_2 vs annotator_3) ...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Sample distances:
#                                          unit_id  chart_id level  dist_12  dist_13  dist_23
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart1__L2         1    L2 0.059479 0.077053 0.056197
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart1__L3         1    L3      NaN      NaN      NaN
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart1__L4         1    L4 0.129179 0.135945 0.126873
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart2__L2         2    L2 0.095340 0.127698 0.092421
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart2__L3         2    L3 0.131507 0.141471 0.125049
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart2__L4         2    L4 0.130863 0.139733 0.103228
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart3__L2         3    L2 0.061411 0.074858 0.065052
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart3__L3         3    L3      NaN      NaN 0.116854
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart3__L4         3    L4 0.152272 0.151110 0.136136
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart4__L2         4    L2 0.067995 0.057503 0.079856
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart4__L3         4    L3      NaN      NaN 0.147825
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart4__L4         4    L4 0.154332 0.156326 0.151459

# %% [markdown]
# ## STEP 4: Krippendorff's alpha with custom BERTScore distance
#
# $$\alpha = 1 - \frac{D_o}{D_e}$$
#
# - **D_o** = mean observed disagreement (average pairwise distance within units, >=2 valid annotators)
# - **D_e** = mean expected disagreement (average over all valid distances in the pool)

# %%
def compute_cross_item_distances_batched(sub_df, ann_col, model_type=MODEL_TYPE, device=DEVICE):
    annotations = sub_df[ann_col].tolist()
    n = len(annotations)

    refs_batch = []
    hyps_batch = []

    for i in range(n):
        for j in range(i + 1, n):
            a, b = annotations[i], annotations[j]
            if is_missing(a) or is_missing(b):
                continue
            refs_batch.append(str(a))
            hyps_batch.append(str(b))

    if not refs_batch:
        return []

    _, _, F1 = bert_score(
        hyps_batch, refs_batch,
        model_type=model_type,
        device=device,
        verbose=False
    )
    return (1.0 - F1.numpy()).tolist()


def krippendorff_alpha_bertscore_correct(sub_df, dist_cols=DIST_COLS):
    unit_mean_dist = sub_df[dist_cols].mean(axis=1, skipna=True)
    valid_units    = unit_mean_dist.notna()
    n_valid        = valid_units.sum()

    if n_valid < 2:
        return np.nan, np.nan, np.nan, n_valid

    D_o = unit_mean_dist[valid_units].mean()

    cross_item_distances = []
    for ann_col in ["annotator_1", "annotator_2", "annotator_3"]:
        print(f"  [{ann_col}] computing cross-item distances "
              f"({sub_df[ann_col].notna().sum()} valid annotations)...")
        cross_item_distances.extend(
            compute_cross_item_distances_batched(sub_df, ann_col)
        )

    if not cross_item_distances:
        return np.nan, np.nan, np.nan, n_valid

    D_e = np.mean(cross_item_distances)
    if D_e == 0:
        return np.nan, np.nan, np.nan, n_valid

    alpha = 1.0 - (D_o / D_e)
    return alpha, D_o, D_e, n_valid

# %% [markdown]
# ## STEP 6: Overall alpha (all dashboards combined)

# %%
print("=" * 60)
print(f"Krippendorff's α — BERTScore ({MODEL_TYPE})")
print("=" * 60)

print("\n[Overall]")
alpha_all, Do_all, De_all, n_all = krippendorff_alpha_bertscore_correct(long_df)
print(f"  α={alpha_all:.4f}  D_o={Do_all:.4f}  D_e={De_all:.4f}  n_valid={n_all}")
# Out:
# ============================================================
# Krippendorff's α — BERTScore (roberta-large)
# ============================================================
#
# [Overall]
#   [annotator_1] computing cross-item distances (122 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (143 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (145 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   α=0.2384  D_o=0.1214  D_e=0.1594  n_valid=143

# %% [markdown]
# ## STEP 7: Alpha per insight level (L2 / L3 / L4)

# %%
print("\n[By Semantic Level]")
level_results = []
for level in ["L2", "L3", "L4"]:
    print(f"\n  Level {level}:")
    sub = long_df[long_df["level"] == level]
    alpha, D_o, D_e, n_valid = krippendorff_alpha_bertscore_correct(sub)
    level_results.append({
        "Level":         level,
        "Alpha":         round(alpha, 4) if not np.isnan(alpha) else "N/A",
        "D_o":           round(D_o, 4)   if not np.isnan(D_o)   else "N/A",
        "D_e":           round(D_e, 4)   if not np.isnan(D_e)   else "N/A",
        "N_units_valid": n_valid,
        "N_units_total": len(sub),
    })
    print(f"  → α={alpha:.4f}  D_o={D_o:.4f}  D_e={D_e:.4f}  "
          f"valid={n_valid}/{len(sub)}")

level_df = pd.DataFrame(level_results)
# Out:
# [By Semantic Level]
#
#   Level L2:
#   [annotator_1] computing cross-item distances (49 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (49 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (49 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.3381  D_o=0.0991  D_e=0.1497  valid=49/49
#
#   Level L3:
#   [annotator_1] computing cross-item distances (24 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (45 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (47 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.1120  D_o=0.1307  D_e=0.1471  valid=45/49
#
#   Level L4:
#   [annotator_1] computing cross-item distances (49 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (49 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (49 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.0361  D_o=0.1353  D_e=0.1403  valid=49/49

# %% [markdown]
# ## STEP 8: Alpha per dashboard

# %%
print("\n[By Dashboard]")
dash_results = []
for row_id in sorted(long_df["row_id"].unique()):
    print(f"\n  Dashboard {row_id[:8]}…:")
    sub = long_df[long_df["row_id"] == row_id]
    alpha, D_o, D_e, n_valid = krippendorff_alpha_bertscore_correct(sub)
    dash_results.append({
        "row_id":        row_id,
        "Alpha":         round(alpha, 4) if not np.isnan(alpha) else "N/A",
        "D_o":           round(D_o, 4)   if not np.isnan(D_o)   else "N/A",
        "D_e":           round(D_e, 4)   if not np.isnan(D_e)   else "N/A",
        "N_units_valid": n_valid,
        "N_units_total": len(sub),
    })
    print(f"  → α={alpha:.4f}  valid={n_valid}/{len(sub)}")

dash_df = pd.DataFrame(dash_results)
# Out:
# [By Dashboard]
#
#   Dashboard 08006d53…:
#   [annotator_1] computing cross-item distances (9 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (12 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (12 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.2584  valid=12/12
#
#   Dashboard 1120a289…:
#   [annotator_1] computing cross-item distances (11 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (14 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (14 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.2777  valid=14/15
#
#   Dashboard 2e5b2881…:
#   [annotator_1] computing cross-item distances (14 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (18 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (18 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.1955  valid=18/18
#
#   Dashboard 511bca34…:
#   [annotator_1] computing cross-item distances (8 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (9 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (9 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.1960  valid=9/9
#
#   Dashboard 723340b5…:
#   [annotator_1] computing cross-item distances (12 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (12 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (12 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.1422  valid=12/12
#
#   Dashboard b164ac02…:
#   [annotator_1] computing cross-item distances (15 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (18 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (18 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.1856  valid=18/18
#
#   Dashboard cfe29540…:
#   [annotator_1] computing cross-item distances (20 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (20 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (21 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.2224  valid=20/21
#
#   Dashboard dc09d834…:
#   [annotator_1] computing cross-item distances (14 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (18 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (18 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.2072  valid=18/18
#
#   Dashboard e743f36f…:
#   [annotator_1] computing cross-item distances (10 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (11 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (11 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.2273  valid=11/12
#
#   Dashboard f451d481…:
#   [annotator_1] computing cross-item distances (9 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_2] computing cross-item distances (11 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   [annotator_3] computing cross-item distances (12 valid annotations)...
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#   → α=0.2941  valid=11/12

# %% [markdown]
# ## STEP 9: Summary printout

# %%
print("\n[Level Summary]")
print(level_df.to_string(index=False))

print("\n[Dashboard Summary]")
print(dash_df.to_string(index=False))
# Out:
# [Level Summary]
# Level  Alpha    D_o    D_e  N_units_valid  N_units_total
#    L2 0.3381 0.0991 0.1497             49             49
#    L3 0.1120 0.1307 0.1471             45             49
#    L4 0.0361 0.1353 0.1403             49             49
#
# [Dashboard Summary]
#                               row_id  Alpha    D_o    D_e  N_units_valid  N_units_total
# 08006d53-f01b-4eb6-a517-8825c184d732 0.2584 0.1094 0.1476             12             12
# 1120a289-6f8e-4498-91d8-59bb0b7bb49d 0.2777 0.1166 0.1614             14             15
# 2e5b2881-e3e3-421f-a3b9-098e326303a3 0.1955 0.1212 0.1506             18             18
# 511bca34-e364-49d6-8cf9-263c3426db13 0.1960 0.1358 0.1689              9              9
# 723340b5-2604-49f0-963a-3699aef72048 0.1422 0.1238 0.1444             12             12
# b164ac02-5f8b-4b10-ad35-afa018951888 0.1856 0.1288 0.1582             18             18
# cfe29540-1433-470e-9dc8-612e018bd8b6 0.2224 0.1181 0.1518             20             21
# dc09d834-178b-48e2-990d-94464475d0fa 0.2072 0.1242 0.1566             18             18
# e743f36f-e3b6-49b6-85a2-c678e553d8a1 0.2273 0.1232 0.1594             11             12
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2 0.2941 0.1144 0.1620             11             12

# %% [markdown]
# ## STEP 10: Moving on to BERTScore

# %%
F1_COLS = {
    "dist_12": "F1_ann1_ann2",
    "dist_13": "F1_ann1_ann3",
    "dist_23": "F1_ann2_ann3",
}

for dist_col, f1_col in F1_COLS.items():
    long_df[f1_col] = 1.0 - long_df[dist_col]  # NaN stays NaN

F1_VALUE_COLS = list(F1_COLS.values())

print("--- Mean Pairwise BERTScore F1 by Level ---")
iaa_results = []
for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level]
    row = {"Level": level}
    for f1_col in F1_VALUE_COLS:
        mean_f1 = sub[f1_col].mean(skipna=True)
        n_valid  = sub[f1_col].notna().sum()
        row[f1_col]               = round(mean_f1, 4)
        row[f1_col + "_n_valid"]  = n_valid
    row["Mean_F1_overall"] = round(
        sub[F1_VALUE_COLS].values.flatten()[
            ~np.isnan(sub[F1_VALUE_COLS].values.flatten())
        ].mean(), 4
    )
    iaa_results.append(row)
    print(f"  {level}: "
          f"ann1-ann2={row['F1_ann1_ann2']:.4f} (n={row['F1_ann1_ann2_n_valid']})  "
          f"ann1-ann3={row['F1_ann1_ann3']:.4f} (n={row['F1_ann1_ann3_n_valid']})  "
          f"ann2-ann3={row['F1_ann2_ann3']:.4f} (n={row['F1_ann2_ann3_n_valid']})  "
          f"mean={row['Mean_F1_overall']:.4f}")

iaa_df = pd.DataFrame(iaa_results)
# Out:
# --- Mean Pairwise BERTScore F1 by Level ---
#   L2: ann1-ann2=0.9027 (n=49)  ann1-ann3=0.8993 (n=49)  ann2-ann3=0.9009 (n=49)  mean=0.9009
#   L3: ann1-ann2=0.8725 (n=24)  ann1-ann3=0.8682 (n=24)  ann2-ann3=0.8699 (n=45)  mean=0.8701
#   L4: ann1-ann2=0.8604 (n=49)  ann1-ann3=0.8596 (n=49)  ann2-ann3=0.8742 (n=49)  mean=0.8647

# %% [markdown]
# ### Qualitative analysis: lowest scores

# %%
print("=== Lowest Pairwise BERTScore F1 Units ===\n")

N_BOTTOM = 5  # how many lowest to inspect per level

for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level].copy()

    # Mean F1 across available pairs per unit
    sub["mean_F1"] = sub[F1_VALUE_COLS].mean(axis=1, skipna=True)

    # Only units with at least one valid pair
    sub_valid = sub[sub["mean_F1"].notna()].sort_values("mean_F1")

    print(f"{'='*70}")
    print(f"LEVEL {level} — Bottom {N_BOTTOM} units by mean pairwise F1")
    print(f"{'='*70}")

    for _, row in sub_valid.head(N_BOTTOM).iterrows():
        print(f"\nunit : {row['unit_id']}")
        print(f"chart: {row['chart_id']} — {row['title']}")
        print(f"F1   : ann1-ann2={row['F1_ann1_ann2']:.4f}  "
              f"ann1-ann3={row['F1_ann1_ann3']:.4f}  "
              f"ann2-ann3={row['F1_ann2_ann3']:.4f}  "
              f"mean={row['mean_F1']:.4f}")
        print(f"ann1 : {row['annotator_1']}")
        print(f"ann2 : {row['annotator_2']}")
        print(f"ann3 : {row['annotator_3']}")
        print()
# Out:
# === Lowest Pairwise BERTScore F1 Units ===
#
# ======================================================================
# LEVEL L2 — Bottom 5 units by mean pairwise F1
# ======================================================================
#
# unit : 511bca34-e364-49d6-8cf9-263c3426db13__chart2__L2
# chart: 2 — Profit Margin by State
# F1   : ann1-ann2=0.8292  ann1-ann3=0.8214  ann2-ann3=0.8391  mean=0.8299
# ann1 : The majority of states show a positive margin of green encoded in 2021, compared to 2020
# ann2 : AK, WY, HI, and ME had N/A value
# ann3 : States with negatives prorit margin are OR, Az, Co, IL, Tx, TN, OH, PA and NC while others in green has positive profit margin
#
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart2__L2
# chart: 2 — 2023 | Sales vs Targets
# F1   : ann1-ann2=0.8519  ann1-ann3=0.8608  ann2-ann3=0.8325  mean=0.8484
# ann1 : Sales started at around £40K in January and ended the year at around £80K, but it did not reach the target
# ann2 : In 2023, the sales vs target, J is 21.7K, F is -7.3K, and M is 3.2K
# ann3 : January, June, August, October, and November were months with sales above target
#
#
# unit : dc09d834-178b-48e2-990d-94464475d0fa__chart5__L2
# chart: 5 — Monthly Orders Details
# F1   : ann1-ann2=0.8297  ann1-ann3=0.8771  ann2-ann3=0.8467  mean=0.8512
# ann1 : The highest orders occurred in November 2019 at around 250 orders
# ann2 : Ranging from 2016 to 2019, almost every month in every year, the number of the later year is more than the earlier
# ann3 : 2019 has the biggest monthly orders compared with 2018, 2017, and 2016
#
#
# unit : 511bca34-e364-49d6-8cf9-263c3426db13__chart3__L2
# chart: 3 — Sales and Profit by Subcategory
# F1   : ann1-ann2=0.8528  ann1-ann3=0.8708  ann2-ann3=0.8742  mean=0.8659
# ann1 : The highest sales by sub-category are Phones, and the highest profit by sub-category is Copiers
# ann2 : Tables, machines, bookcases, and supplies are the subcategories that experiencing loss
# ann3 : Phones has the biggest sales among other product and Fastener is the smallest. In 2021, the categories with losses, from largest to smallest, were Tables, Machines, Supplies, and Bookcases
#
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart4__L2
# chart: 4 — Top 5 Sub-Categories | Sales vs Targets
# F1   : ann1-ann2=0.8677  ann1-ann3=0.9047  ann2-ann3=0.8488  mean=0.8737
# ann1 : Phones led the sub-categories in sales, with +£10.6K above target, while binders and copiers exceeded their targets, chairs lagged by £5.1K, and storage was just £0.9K below its target
# ann2 : Top 5 sub-categories are phones, chairs, binders, and copiers
# ann3 : Binders exceeded target by the largest margin at +13.2K, followed by Copiers at +10.6K, while Chairs and Storage missed target by -5.1K and -0.9K
#
# ======================================================================
# LEVEL L3 — Bottom 5 units by mean pairwise F1
# ======================================================================
#
# unit : dc09d834-178b-48e2-990d-94464475d0fa__chart6__L3
# chart: 6 — Orders by Sub Category Details
# F1   : ann1-ann2=nan  ann1-ann3=nan  ann2-ann3=0.8279  mean=0.8279
# ann1 : None
# ann2 : Order volume is unevenly distributed across sub-categories, with a few categories standing out clearly above the rest
# ann3 : Order volume is dominated by Office Supplies, especially Binders (1,316) and Paper (1,191), while Furniture shows mid-range demand and Technology is uneven, with strong orders for Phones (814) and Accessories (718) but much lower volumes for Copiers (68) and Machines (112)
#
#
# unit : 2e5b2881-e3e3-421f-a3b9-098e326303a3__chart6__L3
# chart: 6 — Sales by Customer
# F1   : ann1-ann2=nan  ann1-ann3=nan  ann2-ann3=0.8317  mean=0.8317
# ann1 : None
# ann2 : Customer sales show a steep ranking pattern, with the top customer clearly ahead but followed by several others at relatively similar lower levels, suggesting concentration at the top without a single extreme outlier dominating the list
# ann3 : Customer sales are led by Raymond Buch (14.20K) and Tom Ashbrook (13.72K), followed by Hunter Lopez (10.52K), Seth Vernon (8.46K), and Grant Thornton (8.17K), with a moderate gap among the top five
#
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart4__L3
# chart: 4 — Top 5 Sub-Categories | Sales vs Targets
# F1   : ann1-ann2=nan  ann1-ann3=nan  ann2-ann3=0.8347  mean=0.8347
# ann1 : None
# ann2 : The leading sub-categories show mixed target performance, with some categories exceeding target while others remain below, even though all belong to the top sales group
# ann3 : Performance is mixed, with Binders (+13.2K) and Phones (+10.6K) posting the strongest positive gaps, Copiers also above target (+3.4K), while Chairs (-5.1K) and Storage (-0.9K) underperformed
#
#
# unit : cfe29540-1433-470e-9dc8-612e018bd8b6__chart5__L3
# chart: 5 — Sales by Sub-Category
# F1   : ann1-ann2=0.8407  ann1-ann3=0.8680  ann2-ann3=0.8252  mean=0.8446
# ann1 : While all sub-categories' sales surpassed the previous year's sales, Tables' sales remain the same as the previous year with no increase (0%)
# ann2 : Phones leading the group with chairs, while the remaining categories form a lower tier with smaller visual differences
# ann3 : All shown sub-categories are at or above previous-year levels, with Binders (+47%), Phones (+33%), and Copiers (+27%) showing the strongest gains, while Tables is flat at 0%, suggesting growth is concentrated in selected items
#
#
# unit : cfe29540-1433-470e-9dc8-612e018bd8b6__chart7__L3
# chart: 7 — Sales by Segments
# F1   : ann1-ann2=0.8563  ann1-ann3=0.8342  ann2-ann3=0.8548  mean=0.8484
# ann1 : The trend also shows an increase in sales toward the end of the year
# ann2 : Consumer stands out as the largest segment by a visible margin, while Corporate forms a middle tier and Home Office is the smallest contributor, creating a clear three-level structure
# ann3 : Consumer is dominant at 332K (45%), followed by Corporate at 242K (33%) and Home Office at 159K (22%), with performance driven more by the two larger segments than Home Office
#
# ======================================================================
# LEVEL L4 — Bottom 5 units by mean pairwise F1
# ======================================================================
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart4__L4
# chart: 4 — Top 5 Sub-Categories | Sales vs Targets
# F1   : ann1-ann2=0.8456  ann1-ann3=0.8368  ann2-ann3=0.8515  mean=0.8446
# ann1 : The target should be adjusted for chairs, as it is higher than the phones' target, which ranked number one in sales, and is a hot commodity these days
# ann2 : This pattern may indicate that high sales alone don't guarantee target attainment, suggesting that some top-performing sub-categories are still underdelivering relative to expectations and may require different pricing, promotion, or inventory strategies than the categories already ahead of target
# ann3 : Above-target performance in Phones, Binders, and Copiers, contrasted with shortfalls in Chairs and Storage, suggests customers may prioritize functional, productivity-related items over larger or space-dependent purchases
#
#
# unit : f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart4__L4
# chart: 4 — Top 10 Products in the West
# F1   : ann1-ann2=0.8457  ann1-ann3=0.8437  ann2-ann3=0.8485  mean=0.8460
# ann1 : Canon ImageCLASS 2200 advanced copier outperforms other listed products, suggesting strong market fit and indicating the business could benefit from prioritizing stock availability and marketing this product to sustain demand
# ann2 : This pattern may indicate that, beyond the two standout products, the products ranked three to ten still form a strong secondary tier, suggesting a valuable opportunity to widen the next sales period’s growth base by promoting these products more actively rather than relying too heavily on only the top leaders
# ann3 : The copiers, office furniture, and business equipment among the top selling products in the West suggests regional demand may be affected by workplace and business purchasing needs rather than mainly by casual consumer items, which could reflect a customer base with stronger demand for functional, higher utility office items
#
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart6__L4
# chart: 6 — Top 5 Manufacturers chart | Sales vs Targets
# F1   : ann1-ann2=0.8501  ann1-ann3=0.8441  ann2-ann3=0.8509  mean=0.8484
# ann1 : Even though the Global and Hon have their sales ranked in 2nd and 3rd place, the target is too high, and may suggest the need to lower the target
# ann2 : This contrast may indicate that strong sales volume is not distributed equally in terms of target achievement across suppliers, suggesting that some manufacturer relationships are converting demand more effectively
# ann3 : Canon, GBC, and Fellowes being above target while Global and Hon fall short suggests manufacturer performance may depend more on product-market fit, pricing strength, or demand reliability than supplier size alone
#
#
# unit : 2e5b2881-e3e3-421f-a3b9-098e326303a3__chart3__L4
# chart: 3 — Sales by Category
# F1   : ann1-ann2=0.8404  ann1-ann3=0.8538  ann2-ann3=0.8513  mean=0.8485
# ann1 : Technology surpassing office supplies may suggest that the higher unit price surpasses the sales with the quantity
# ann2 : This pattern may suggest that revenue is relatively diversified across the three major categories, with Technology providing the strongest lead, indicating a balanced portfolio where growth is not dependent on only one category but still benefits from a clear top performer
# ann3 : Technology leading in sales, combined with stronger growth in Office Supplies and weaker growth in Furniture, suggests demand may be driven more by productivity and workplace needs, while furniture purchases may behave as slower-moving goods
#
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart3__L4
# chart: 3 — Segment | Sales vs Targets
# F1   : ann1-ann2=0.8459  ann1-ann3=0.8408  ann2-ann3=0.8636  mean=0.8501
# ann1 : Strategy should probe what is driving Home Office success and apply its tactics to Consumer and Corporate segments to close their gaps
# ann2 : This contrast may indicate that target-setting or demand strength differs substantially by segment, suggesting that the business may be underperforming in its largest customer groups while a smaller segment shows relatively stronger conversion against expectations
# ann3 : Home Office being the only segment above target suggests demand may be shifting toward smaller or more flexible purchasing needs, possibly reflecting stronger work-from-home momentum or independent buyer behavior

# %% [markdown]
# ### Qualitative analysis: highest scores

# %%
print("\n=== Highest Pairwise BERTScore F1 Units ===\n")

N_TOP = 3

for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level].copy()
    sub["mean_F1"] = sub[F1_VALUE_COLS].mean(axis=1, skipna=True)
    sub_valid = sub[sub["mean_F1"].notna()].sort_values("mean_F1", ascending=False)

    print(f"{'='*70}")
    print(f"LEVEL {level} — Top {N_TOP} units by mean pairwise F1")
    print(f"{'='*70}")

    for _, row in sub_valid.head(N_TOP).iterrows():
        print(f"\nunit : {row['unit_id']}")
        print(f"chart: {row['chart_id']} — {row['title']}")
        print(f"F1   : ann1-ann2={row['F1_ann1_ann2']:.4f}  "
              f"ann1-ann3={row['F1_ann1_ann3']:.4f}  "
              f"ann2-ann3={row['F1_ann2_ann3']:.4f}  "
              f"mean={row['mean_F1']:.4f}")
        print(f"ann1 : {row['annotator_1']}")
        print(f"ann2 : {row['annotator_2']}")
        print(f"ann3 : {row['annotator_3']}")
        print()
# Out:
# === Highest Pairwise BERTScore F1 Units ===
#
# ======================================================================
# LEVEL L2 — Top 3 units by mean pairwise F1
# ======================================================================
#
# unit : 1120a289-6f8e-4498-91d8-59bb0b7bb49d__chart1__L2
# chart: 1 — Scoreboard Overview
# F1   : ann1-ann2=0.9722  ann1-ann3=0.9484  ann2-ann3=0.9426  mean=0.9544
# ann1 : Sales are 733,215, profit is 93,439, and the number of orders is 1,687
# ann2 : Sales are 733,215, profit is 93.439, and orders are 1,687
# ann3 : Sales value is 733,215, Profit value is 93,439, and Orders values is 1,687
#
#
# unit : 08006d53-f01b-4eb6-a517-8825c184d732__chart1__L2
# chart: 1 — Scoreboard & Barchart
# F1   : ann1-ann2=0.9703  ann1-ann3=0.9444  ann2-ann3=0.9394  mean=0.9513
# ann1 : Total sales are $745.6K, total orders are $3.4K, and sales are $5.4K above the target
# ann2 : Total sales are $745.6K, total number of orders is 3.4K, and the sales are $5.4 above target
# ann3 : Total sales is 745.6K, Total Orders is 3.4K and Sales is above target with 5.4K in value
#
#
# unit : cfe29540-1433-470e-9dc8-612e018bd8b6__chart1__L2
# chart: 1 — Scoreboard Overview
# F1   : ann1-ann2=0.9606  ann1-ann3=0.9433  ann2-ann3=0.9344  mean=0.9461
# ann1 : Sales are about $733.2K, profit is $93.4K, orders are 1,687, and quantity is 12,476 units
# ann2 : Total sales are $733.2K, total profit is $93.4K, total orders are 1,687, and the number of quantity is 12,476
# ann3 : 2022 Sales is 733.2K, Profit is 93.4K, Orders count is 1,687, and Quantity sold is 12,476
#
# ======================================================================
# LEVEL L3 — Top 3 units by mean pairwise F1
# ======================================================================
#
# unit : 08006d53-f01b-4eb6-a517-8825c184d732__chart4__L3
# chart: 4 — Top 5 States by Sales
# F1   : ann1-ann2=nan  ann1-ann3=nan  ann2-ann3=0.9096  mean=0.9096
# ann1 : None
# ann2 : Target performance is mixed across the top states, with California, New York, and Washington sitting above target while Texas and Pennsylvania fall below, creating a clear split between overperforming and underperforming states
# ann3 : Among the top five states, California, New York, and Washington all exceed their sales targets, with California has the largest positive gap (+9.1K), while Texas and Pennsylvania sales fall below target, showing that strong sales rankings do not always translate into target achievement
#
#
# unit : 1120a289-6f8e-4498-91d8-59bb0b7bb49d__chart2__L3
# chart: 2 — Top 10 Profitable States
# F1   : ann1-ann2=nan  ann1-ann3=nan  ann2-ann3=0.8967  mean=0.8967
# ann1 : None
# ann2 : Profitability drops off sharply after the leading states, with California and New York standing clearly ahead of the rest, while the remaining states form a much lower tier
# ann3 : Profit is heavily concentrated in the top three states, with California (29,366), New York (24,357), and Washington (17,257) far ahead of the rest, followed by a sharp drop to much smaller profit contributions from the other states
#
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart6__L3
# chart: 6 — Top 5 Manufacturers chart | Sales vs Targets
# F1   : ann1-ann2=nan  ann1-ann3=nan  ann2-ann3=0.8927  mean=0.8927
# ann1 : None
# ann2 : Manufacturer performance against target is uneven, with some of the leading manufacturers exceeding target and others falling short, despite all appearing in the top sales group
# ann3 : Sales versus target is mixed across the top five manufacturers, with Fellowes, GBC, and Canon exceeding target, while Global and especially Hon fall short, showing uneven attainment among leading manufacturers
#
# ======================================================================
# LEVEL L4 — Top 3 units by mean pairwise F1
# ======================================================================
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart1__L4
# chart: 1 — Scoreboard overview
# F1   : ann1-ann2=0.8841  ann1-ann3=0.8724  ann2-ann3=0.8906  mean=0.8823
# ann1 : However, while the company is successfully expanding revenue and volume, the return rates should be monitored to ensure growth does not erode profitability or customer satisfaction
# ann2 : This pattern may indicate that the business is scaling in revenue and volume, but the much faster rise in returns could suggest emerging pressure on product quality, fulfillment accuracy, or customer expectation management
# ann3 : Rising Sales, Profit, and Quantity, combined with a sharper increase in Returns, suggests the business may be growing through stronger demand and transaction volume, but growth quality may be pressured by defects, mismatch, or fulfillment issues
#
#
# unit : 08006d53-f01b-4eb6-a517-8825c184d732__chart1__L4
# chart: 1 — Scoreboard & Barchart
# F1   : ann1-ann2=0.8706  ann1-ann3=0.8733  ann2-ann3=0.8993  mean=0.8811
# ann1 : The first two quarters' trend shows weak sales and orders, with sales performance below the target from February to May, suggesting the need for a push with marketing and promotional strategy
# ann2 : This pattern may indicate that overall performance strengthened as the year progressed, suggesting the business relied on stronger late-year execution to finish above target
# ann3 : The year-end surge in sales and orders suggests that 2023 performance was strongly supported by seasonal demand, promotional activity, or year-end purchasing cycles. While this helped the business recover from weaker first-half performance and finish above target, it may also indicate that overall revenue growth was heavily dependent on the final quarter rather than being consistent throughout the year
#
#
# unit : 723340b5-2604-49f0-963a-3699aef72048__chart4__L4
# chart: 4 — Return (sales) by sub-category
# F1   : ann1-ann2=0.8783  ann1-ann3=0.8797  ann2-ann3=0.8818  mean=0.8799
# ann1 : Sub-categories of Phones and Chairs, having both the highest sales and returns, may need further analysis and a strategy to reduce the returns of the products to minimize loss
# ann2 : This pattern may suggest that the products generating the most revenue are also exposing the business to the greatest return risk, indicating that sales success in those sub-categories may come with higher post-purchase issues, service burden, or margin leakage
# ann3 : The concentration of returns in Phones, Chairs, Storage, and Copiers suggests that some of the business biggest selling categories may also carry higher post purchase risk, which could indicate that fast selling products are not always translating into high quality revenue because return exposure may be eroding part of profitability

# %% [markdown]
# ### Distribution summary per level

# %%
print("\n=== F1 Distribution Summary per Level ===\n")
for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level].copy()
    sub["mean_F1"] = sub[F1_VALUE_COLS].mean(axis=1, skipna=True)
    vals = sub["mean_F1"].dropna()
    print(f"  {level}: min={vals.min():.4f}  "
          f"Q1={vals.quantile(0.25):.4f}  "
          f"median={vals.quantile(0.50):.4f}  "
          f"Q3={vals.quantile(0.75):.4f}  "
          f"max={vals.max():.4f}")
# Out:
# === F1 Distribution Summary per Level ===
#
#   L2: min=0.8299  Q1=0.8827  median=0.8970  Q3=0.9221  max=0.9544
#   L3: min=0.8279  Q1=0.8612  median=0.8720  Q3=0.8814  max=0.9096
#   L4: min=0.8446  Q1=0.8581  median=0.8657  Q3=0.8725  max=0.8823

# %% [markdown]
# ## STEP 11: ROUGE trial

# %%
from rouge_score import rouge_scorer
import numpy as np

# ============================================================
# ROUGE scorer setup
# We use ROUGE-1, ROUGE-2, and ROUGE-L
# ============================================================
scorer = rouge_scorer.RougeScorer(
    ["rouge1", "rouge2", "rougeL"],
    use_stemmer=True
)

# ============================================================
# Pairwise ROUGE F1 between two text lists
# Returns dict of {metric: numpy array of scores}
# Missing values return np.nan
# ============================================================
def rouge_pairwise_batch(refs, hyps):
    assert len(refs) == len(hyps)

    results = {
        "rouge1": np.full(len(refs), np.nan),
        "rouge2": np.full(len(refs), np.nan),
        "rougeL": np.full(len(refs), np.nan),
    }

    for i, (r, h) in enumerate(zip(refs, hyps)):
        if is_missing(r) or is_missing(h):
            continue
        scores = scorer.score(str(r), str(h))
        results["rouge1"][i] = scores["rouge1"].fmeasure
        results["rouge2"][i] = scores["rouge2"].fmeasure
        results["rougeL"][i] = scores["rougeL"].fmeasure

    return results

# ============================================================
# Compute pairwise ROUGE for all annotator pairs
# ============================================================
ROUGE_METRICS = ["rouge1", "rouge2", "rougeL"]
ROUGE_PAIR_COLS = {}  # maps (pair_key, metric) -> column name

for (col_a, col_b) in ANNOTATOR_PAIRS:
    suffix_a = col_a.split("_")[-1]
    suffix_b = col_b.split("_")[-1]
    pair_key = f"{suffix_a}{suffix_b}"

    print(f"Computing ROUGE for ann{suffix_a} vs ann{suffix_b} ...")
    results = rouge_pairwise_batch(
        long_df[col_a].tolist(),
        long_df[col_b].tolist()
    )

    for metric in ROUGE_METRICS:
        col_name = f"rouge_{metric}_{pair_key}"
        long_df[col_name] = results[metric]
        ROUGE_PAIR_COLS[(pair_key, metric)] = col_name

print("\nDone. Sample:")
sample_cols = ["unit_id", "level"] + list(ROUGE_PAIR_COLS.values())[:6]
print(long_df[sample_cols].head(6).to_string(index=False))

# ============================================================
# Mean pairwise ROUGE F1 per level
# ============================================================
print("\n=== Mean Pairwise ROUGE F1 by Level ===\n")

rouge_iaa_results = []
for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level]
    row = {"Level": level}

    for metric in ROUGE_METRICS:
        pair_scores = []
        pair_details = []

        for (col_a, col_b) in ANNOTATOR_PAIRS:
            suffix_a = col_a.split("_")[-1]
            suffix_b = col_b.split("_")[-1]
            pair_key = f"{suffix_a}{suffix_b}"
            col_name = ROUGE_PAIR_COLS[(pair_key, metric)]

            mean_score = sub[col_name].mean(skipna=True)
            n_valid    = sub[col_name].notna().sum()
            pair_scores.append(mean_score)
            pair_details.append(f"ann{suffix_a}-ann{suffix_b}={mean_score:.4f}(n={n_valid})")

            row[f"{metric}_ann{suffix_a}_ann{suffix_b}"] = round(mean_score, 4)
            row[f"{metric}_ann{suffix_a}_ann{suffix_b}_n"] = n_valid

        row[f"{metric}_mean"] = round(np.nanmean(pair_scores), 4)
        print(f"  {level} {metric.upper():8s}: "
              f"{' | '.join(pair_details)} | mean={row[f'{metric}_mean']:.4f}")

    rouge_iaa_results.append(row)
    print()

rouge_iaa_df = pd.DataFrame(rouge_iaa_results)

# ============================================================
# Distribution summary per level per metric
# ============================================================
print("\n=== ROUGE Distribution Summary per Level ===\n")
for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level]
    print(f"  {level}:")
    for metric in ROUGE_METRICS:
        # Pool all pair scores for this level+metric
        pair_cols = [ROUGE_PAIR_COLS[(f"{a.split('_')[-1]}{b.split('_')[-1]}", metric)]
                     for (a, b) in ANNOTATOR_PAIRS]
        vals = sub[pair_cols].values.flatten()
        vals = vals[~np.isnan(vals)]
        print(f"    {metric.upper():8s}: min={vals.min():.4f}  "
              f"Q1={vals.quantile(0.25) if hasattr(vals, 'quantile') else np.percentile(vals, 25):.4f}  "
              f"median={np.median(vals):.4f}  "
              f"Q3={np.percentile(vals, 75):.4f}  "
              f"max={vals.max():.4f}")
    print()
# Out:
# Computing ROUGE for ann1 vs ann2 ...
# Computing ROUGE for ann1 vs ann3 ...
# Computing ROUGE for ann2 vs ann3 ...
#
# Done. Sample:
#                                          unit_id level  rouge_rouge1_12  rouge_rouge2_12  rouge_rougeL_12  rouge_rouge1_13  rouge_rouge2_13  rouge_rougeL_13
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart1__L2    L2         0.727273         0.285714         0.590909         0.700000         0.315789         0.600000
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart1__L3    L3              NaN              NaN              NaN              NaN              NaN              NaN
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart1__L4    L4         0.206897         0.000000         0.137931         0.257143         0.000000         0.171429
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart2__L2    L2         0.352941         0.000000         0.235294         0.378378         0.000000         0.270270
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart2__L3    L3         0.367816         0.117647         0.275862         0.351648         0.044944         0.263736
# f451d481-b828-40ed-a9a4-fc7fd6d6caf2__chart2__L4    L4         0.388889         0.085714         0.277778         0.359551         0.091954         0.224719
#
# === Mean Pairwise ROUGE F1 by Level ===
#
#   L2 ROUGE1  : ann1-ann2=0.4888(n=49) | ann1-ann3=0.4580(n=49) | ann2-ann3=0.5161(n=49) | mean=0.4876
#   L2 ROUGE2  : ann1-ann2=0.2005(n=49) | ann1-ann3=0.1750(n=49) | ann2-ann3=0.2311(n=49) | mean=0.2022
#   L2 ROUGEL  : ann1-ann2=0.3827(n=49) | ann1-ann3=0.3720(n=49) | ann2-ann3=0.4183(n=49) | mean=0.3910
#
#   L3 ROUGE1  : ann1-ann2=0.2781(n=24) | ann1-ann3=0.2687(n=24) | ann2-ann3=0.3400(n=45) | mean=0.2956
#   L3 ROUGE2  : ann1-ann2=0.0629(n=24) | ann1-ann3=0.0501(n=24) | ann2-ann3=0.1045(n=45) | mean=0.0725
#   L3 ROUGEL  : ann1-ann2=0.1963(n=24) | ann1-ann3=0.1920(n=24) | ann2-ann3=0.2548(n=45) | mean=0.2144
#
#   L4 ROUGE1  : ann1-ann2=0.2129(n=49) | ann1-ann3=0.2332(n=49) | ann2-ann3=0.3131(n=49) | mean=0.2530
#   L4 ROUGE2  : ann1-ann2=0.0183(n=49) | ann1-ann3=0.0249(n=49) | ann2-ann3=0.0610(n=49) | mean=0.0347
#   L4 ROUGEL  : ann1-ann2=0.1436(n=49) | ann1-ann3=0.1444(n=49) | ann2-ann3=0.1811(n=49) | mean=0.1564
#
#
# === ROUGE Distribution Summary per Level ===
#
#   L2:
#     ROUGE1  : min=0.0606  Q1=0.3381  median=0.4615  Q3=0.6450  max=0.9630
#     ROUGE2  : min=0.0000  Q1=0.0626  median=0.1538  Q3=0.3117  max=0.8800
#     ROUGEL  : min=0.0606  Q1=0.2389  median=0.3478  Q3=0.5298  max=0.9630
#
#   L3:
#     ROUGE1  : min=0.0455  Q1=0.2222  median=0.3188  Q3=0.3729  max=0.5357
#     ROUGE2  : min=0.0000  Q1=0.0000  median=0.0667  Q3=0.1176  max=0.2963
#     ROUGEL  : min=0.0408  Q1=0.1633  median=0.2278  Q3=0.2745  max=0.4333
#
#   L4:
#     ROUGE1  : min=0.0690  Q1=0.1835  median=0.2462  Q3=0.3047  max=0.4773
#     ROUGE2  : min=0.0000  Q1=0.0000  median=0.0256  Q3=0.0460  max=0.2439
#     ROUGEL  : min=0.0417  Q1=0.1197  median=0.1505  Q3=0.1788  max=0.4000

# %%
# ============================================================
# Bottom 5 units per level by mean ROUGE-L (most discriminative)
# ============================================================
print("\n=== Lowest ROUGE-L Units per Level ===\n")

for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level].copy()

    rougeL_cols = [ROUGE_PAIR_COLS[(f"{a.split('_')[-1]}{b.split('_')[-1]}", "rougeL")]
                   for (a, b) in ANNOTATOR_PAIRS]
    sub["mean_rougeL"] = sub[rougeL_cols].mean(axis=1, skipna=True)
    sub_valid = sub[sub["mean_rougeL"].notna()].sort_values("mean_rougeL")

    print(f"{'='*70}")
    print(f"LEVEL {level} — Bottom 5 by mean ROUGE-L")
    print(f"{'='*70}")

    for _, row in sub_valid.head(5).iterrows():
        print(f"\nunit : {row['unit_id']}")
        print(f"chart: {row['chart_id']} — {row['title']}")
        print(f"ROUGE-L: {row['mean_rougeL']:.4f}")
        print(f"ann1 : {row['annotator_1']}")
        print(f"ann2 : {row['annotator_2']}")
        print(f"ann3 : {row['annotator_3']}")
# Out:
# === Lowest ROUGE-L Units per Level ===
#
# ======================================================================
# LEVEL L2 — Bottom 5 by mean ROUGE-L
# ======================================================================
#
# unit : 511bca34-e364-49d6-8cf9-263c3426db13__chart2__L2
# chart: 2 — Profit Margin by State
# ROUGE-L: 0.0969
# ann1 : The majority of states show a positive margin of green encoded in 2021, compared to 2020
# ann2 : AK, WY, HI, and ME had N/A value
# ann3 : States with negatives prorit margin are OR, Az, Co, IL, Tx, TN, OH, PA and NC while others in green has positive profit margin
#
# unit : dc09d834-178b-48e2-990d-94464475d0fa__chart5__L2
# chart: 5 — Monthly Orders Details
# ROUGE-L: 0.1174
# ann1 : The highest orders occurred in November 2019 at around 250 orders
# ann2 : Ranging from 2016 to 2019, almost every month in every year, the number of the later year is more than the earlier
# ann3 : 2019 has the biggest monthly orders compared with 2018, 2017, and 2016
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart2__L2
# chart: 2 — 2023 | Sales vs Targets
# ROUGE-L: 0.1536
# ann1 : Sales started at around £40K in January and ended the year at around £80K, but it did not reach the target
# ann2 : In 2023, the sales vs target, J is 21.7K, F is -7.3K, and M is 3.2K
# ann3 : January, June, August, October, and November were months with sales above target
#
# unit : 511bca34-e364-49d6-8cf9-263c3426db13__chart3__L2
# chart: 3 — Sales and Profit by Subcategory
# ROUGE-L: 0.1701
# ann1 : The highest sales by sub-category are Phones, and the highest profit by sub-category is Copiers
# ann2 : Tables, machines, bookcases, and supplies are the subcategories that experiencing loss
# ann3 : Phones has the biggest sales among other product and Fastener is the smallest. In 2021, the categories with losses, from largest to smallest, were Tables, Machines, Supplies, and Bookcases
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart6__L2
# chart: 6 — Top 5 Manufacturers chart | Sales vs Targets
# ROUGE-L: 0.2366
# ann1 : Canon leads with +£6.1K sales above the target, followed by GBC and Fellowes, who have met their targets, while the Global and Hon manufacturers have lagged behind theirs
# ann2 : Top 5 manufacturers are Canon, Global, Hon, GBC, and Fellowes
# ann3 : Fellowes exceeded target by +9.8K, followed by GBC (+6.8K) and Canon (+6.1K), while Global (-3.9K) and Hon (-11.3K) below target
# ======================================================================
# LEVEL L3 — Bottom 5 by mean ROUGE-L
# ======================================================================
#
# unit : cfe29540-1433-470e-9dc8-612e018bd8b6__chart7__L3
# chart: 7 — Sales by Segments
# ROUGE-L: 0.1232
# ann1 : The trend also shows an increase in sales toward the end of the year
# ann2 : Consumer stands out as the largest segment by a visible margin, while Corporate forms a middle tier and Home Office is the smallest contributor, creating a clear three-level structure
# ann3 : Consumer is dominant at 332K (45%), followed by Corporate at 242K (33%) and Home Office at 159K (22%), with performance driven more by the two larger segments than Home Office
#
# unit : dc09d834-178b-48e2-990d-94464475d0fa__chart5__L3
# chart: 5 — Monthly Orders Details
# ROUGE-L: 0.1288
# ann1 : The yearly trend over four years shows that the orders are increasing each year, while the monthly trends suggest the same patterns in each year, where orders are surging starting from September throughout the end of the year
# ann2 : Orders are generally rising over months while over years it shares a seasonal pattern
# ann3 : Across all four years, monthly orders were moderate from January to August, rose sharply in September, dipped in October, and rebounded strongly in November, with 2019 consistently recording the highest order levels and largest peak
#
# unit : dc09d834-178b-48e2-990d-94464475d0fa__chart6__L3
# chart: 6 — Orders by Sub Category Details
# ROUGE-L: 0.1290
# ann1 : None
# ann2 : Order volume is unevenly distributed across sub-categories, with a few categories standing out clearly above the rest
# ann3 : Order volume is dominated by Office Supplies, especially Binders (1,316) and Paper (1,191), while Furniture shows mid-range demand and Technology is uneven, with strong orders for Phones (814) and Accessories (718) but much lower volumes for Copiers (68) and Machines (112)
#
# unit : dc09d834-178b-48e2-990d-94464475d0fa__chart3__L3
# chart: 3 — Customers by # Orders Placed Summary
# ROUGE-L: 0.1296
# ann1 : This pattern may suggest a normal distribution with slight right skew, suggesting customers may have repeated orders throughout the year
# ann2 : the distribution is concentrated in the middle, it peaks on 5-7, then tapering off
# ann3 : Customer count rises from low order frequency to a peak at 5 orders, remains high through 7 orders, then declines toward higher order counts, showing most customers place a middle range number of orders
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart4__L3
# chart: 4 — Top 5 Sub-Categories | Sales vs Targets
# ROUGE-L: 0.1404
# ann1 : None
# ann2 : The leading sub-categories show mixed target performance, with some categories exceeding target while others remain below, even though all belong to the top sales group
# ann3 : Performance is mixed, with Binders (+13.2K) and Phones (+10.6K) posting the strongest positive gaps, Copiers also above target (+3.4K), while Chairs (-5.1K) and Storage (-0.9K) underperformed
# ======================================================================
# LEVEL L4 — Bottom 5 by mean ROUGE-L
# ======================================================================
#
# unit : 2e5b2881-e3e3-421f-a3b9-098e326303a3__chart1__L4
# chart: 1 — Scoreboard Overview
# ROUGE-L: 0.0803
# ann1 : The lower profit rate at the end of the year may suggest a promotional strategy where sales depend on the discounted price, so the profit margin is small
# ann2 : This pattern may indicate that the business is expanding across both demand and customer reach, although sustained growth in all four metrics also suggests that operational capacity and customer retention will become increasingly important to maintain performance quality
# ann3 : Orders growing much faster than Customers, while Sales and Profit rise more moderately, suggests growth may come mainly from higher purchase frequency or repeat transactions from existing customers rather than new customer expansion
#
# unit : dc09d834-178b-48e2-990d-94464475d0fa__chart6__L4
# chart: 6 — Orders by Sub Category Details
# ROUGE-L: 0.0991
# ann1 : These two highest-order placements suggest high sales volume due to low per-unit price, with patterns similar to those of other sub-categories of office supplies
# ann2 : the wide disparity over the subcategory suggesting that some product has a strong market fit but also revealing some weak market fit product that need to be reviewed or repositioned
# ann3 : The dominance of Binders and Paper, along with strong volume in other Office Supplies, suggests order activity may be driven by routine replenishment rather than infrequent purchases, indicating demand is more consistent in operational items than in Furniture or parts of Technology
#
# unit : dc09d834-178b-48e2-990d-94464475d0fa__chart5__L4
# chart: 5 — Monthly Orders Details
# ROUGE-L: 0.1053
# ann1 : The yearly increase may suggest inflation, while the monthly trend is always increasing from September, suggesting holiday season demands
# ann2 : the seasonal pattern, spike and dip, should be indicate the urgency to do an alignment for staffing, inventory, etc
# ann3 : The recurring September to November surge suggests a strong late-year demand cycle, possibly driven by budget spending, promotions, or holiday purchasing. The higher 2019 level may also indicate stronger market traction or more effective programs over year
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart5__L4
# chart: 5 — Sales by Location | Top 5 States
# ROUGE-L: 0.1077
# ann1 : This geographic condition suggests expansion into mid-tier states could be the next growth target
# ann2 : This coastal concentration may indicate that the business is strongest in larger, denser, and more established markets, suggesting that inland states remain comparatively less penetrated and may represent additional room for expansion
# ann3 : Sales concentration in California, New York, and a few other states, alongside many smaller bubbles elsewhere, suggests revenue may depend on high-density markets with stronger customer concentration, while geographic depth remains uneven
#
# unit : b164ac02-5f8b-4b10-ad35-afa018951888__chart2__L4
# chart: 2 — 2023 | Sales vs Targets
# ROUGE-L: 0.1138
# ann1 : In conclusion, sales improved over time, with high‑performing later months helping lift weaker early‑year periods in the next cycle
# ann2 : This uneven pattern may indicate that sales attainment is still dependent on stronger late-year execution, suggesting that the business may face inconsistent momentum across months and could be relying on a narrower set of peak periods to close the target gap
# ann3 : The shift from weaker target achievement earlier in the year to stronger later performance suggests the business may have benefited from second-half demand, better execution, or seasonal conditions, indicating annual performance was recovered more by late-year acceleration than steady sales

# %% [markdown]
# ### BLEU Trial

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

nltk.download('punkt')
nltk.download('punkt_tab')

smoother = SmoothingFunction().method1

def bleu_pairwise_batch(refs, hyps):
    assert len(refs) == len(hyps)
    results = {
        "bleu1": np.full(len(refs), np.nan),
        "bleu2": np.full(len(refs), np.nan),
        "bleu4": np.full(len(refs), np.nan),
    }
    for i, (r, h) in enumerate(zip(refs, hyps)):
        if is_missing(r) or is_missing(h):
            continue
        ref_tokens = nltk.word_tokenize(str(r).lower())
        hyp_tokens = nltk.word_tokenize(str(h).lower())
        results["bleu1"][i] = sentence_bleu(
            [ref_tokens], hyp_tokens,
            weights=(1, 0, 0, 0),
            smoothing_function=smoother
        )
        results["bleu2"][i] = sentence_bleu(
            [ref_tokens], hyp_tokens,
            weights=(0.5, 0.5, 0, 0),
            smoothing_function=smoother
        )
        results["bleu4"][i] = sentence_bleu(
            [ref_tokens], hyp_tokens,
            weights=(0.25, 0.25, 0.25, 0.25),
            smoothing_function=smoother
        )
    return results

BLEU_METRICS = ["bleu1", "bleu2", "bleu4"]
BLEU_PAIR_COLS = {}

for (col_a, col_b) in ANNOTATOR_PAIRS:
    suffix_a = col_a.split("_")[-1]
    suffix_b = col_b.split("_")[-1]
    pair_key = f"{suffix_a}{suffix_b}"
    print(f"Computing BLEU for ann{suffix_a} vs ann{suffix_b} ...")
    bleu_results = bleu_pairwise_batch(
        long_df[col_a].tolist(),
        long_df[col_b].tolist()
    )
    for metric in BLEU_METRICS:
        col_name = f"bleu_{metric}_{pair_key}"
        long_df[col_name] = bleu_results[metric]
        BLEU_PAIR_COLS[(pair_key, metric)] = col_name

print("\n=== Mean Pairwise BLEU by Level ===\n")
bleu_iaa_results = []
for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level]
    row = {"Level": level}
    for metric in BLEU_METRICS:
        pair_scores = []
        pair_details = []
        for (col_a, col_b) in ANNOTATOR_PAIRS:
            suffix_a = col_a.split("_")[-1]
            suffix_b = col_b.split("_")[-1]
            pair_key = f"{suffix_a}{suffix_b}"
            col_name = BLEU_PAIR_COLS[(pair_key, metric)]
            mean_score = sub[col_name].mean(skipna=True)
            n_valid    = sub[col_name].notna().sum()
            pair_scores.append(mean_score)
            pair_details.append(f"ann{suffix_a}-ann{suffix_b}={mean_score:.4f}(n={n_valid})")
            row[f"{metric}_ann{suffix_a}_ann{suffix_b}"] = round(mean_score, 4)
        row[f"{metric}_mean"] = round(np.nanmean(pair_scores), 4)
        print(f"  {level} {metric.upper():6s}: "
              f"{' | '.join(pair_details)} | mean={row[f'{metric}_mean']:.4f}")
    bleu_iaa_results.append(row)
    print()

bleu_iaa_df = pd.DataFrame(bleu_iaa_results)

print("\n=== BLEU Distribution Summary per Level ===\n")
for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level]
    print(f"  {level}:")
    for metric in BLEU_METRICS:
        pair_cols = [BLEU_PAIR_COLS[(f"{a.split('_')[-1]}{b.split('_')[-1]}", metric)]
                     for (a, b) in ANNOTATOR_PAIRS]
        vals = sub[pair_cols].values.flatten()
        vals = vals[~np.isnan(vals)]
        print(f"    {metric.upper():6s}: min={vals.min():.4f}  "
              f"median={np.median(vals):.4f}  "
              f"max={vals.max():.4f}")
    print()
# Out:
# Computing BLEU for ann1 vs ann2 ...
# Computing BLEU for ann1 vs ann3 ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Computing BLEU for ann2 vs ann3 ...
#
# === Mean Pairwise BLEU by Level ===
#
#   L2 BLEU1 : ann1-ann2=0.3881(n=49) | ann1-ann3=0.3282(n=49) | ann2-ann3=0.3973(n=49) | mean=0.3712
#   L2 BLEU2 : ann1-ann2=0.2424(n=49) | ann1-ann3=0.1823(n=49) | ann2-ann3=0.2366(n=49) | mean=0.2204
#   L2 BLEU4 : ann1-ann2=0.0955(n=49) | ann1-ann3=0.0703(n=49) | ann2-ann3=0.0936(n=49) | mean=0.0865
#
#   L3 BLEU1 : ann1-ann2=0.2307(n=24) | ann1-ann3=0.2260(n=24) | ann2-ann3=0.2770(n=45) | mean=0.2446
#   L3 BLEU2 : ann1-ann2=0.1059(n=24) | ann1-ann3=0.1150(n=24) | ann2-ann3=0.1547(n=45) | mean=0.1252
#   L3 BLEU4 : ann1-ann2=0.0378(n=24) | ann1-ann3=0.0389(n=24) | ann2-ann3=0.0500(n=45) | mean=0.0422
#
#   L4 BLEU1 : ann1-ann2=0.1757(n=49) | ann1-ann3=0.1874(n=49) | ann2-ann3=0.2430(n=49) | mean=0.2020
#   L4 BLEU2 : ann1-ann2=0.0462(n=49) | ann1-ann3=0.0594(n=49) | ann2-ann3=0.1016(n=49) | mean=0.0691
#   L4 BLEU4 : ann1-ann2=0.0136(n=49) | ann1-ann3=0.0144(n=49) | ann2-ann3=0.0286(n=49) | mean=0.0189
#
#
# === BLEU Distribution Summary per Level ===
#
#   L2:
#     BLEU1 : min=0.0085  median=0.3684  max=0.9286
#     BLEU2 : min=0.0021  median=0.1980  max=0.8864
#     BLEU4 : min=0.0012  median=0.0438  max=0.8555
#
#   L3:
#     BLEU1 : min=0.0244  median=0.2571  max=0.5000
#     BLEU2 : min=0.0078  median=0.1263  max=0.3451
#     BLEU4 : min=0.0045  median=0.0203  max=0.2634
#
#   L4:
#     BLEU1 : min=0.0193  median=0.2000  max=0.4286
#     BLEU2 : min=0.0045  median=0.0604  max=0.2598
#     BLEU4 : min=0.0023  median=0.0116  max=0.1590

# %% [markdown]
# ### METEOR Trial

# %%
from nltk.translate.meteor_score import meteor_score
nltk.download('wordnet')

def meteor_pairwise_batch(refs, hyps):
    assert len(refs) == len(hyps)
    results = {"meteor": np.full(len(refs), np.nan)}
    for i, (r, h) in enumerate(zip(refs, hyps)):
        if is_missing(r) or is_missing(h):
            continue
        ref_tokens = nltk.word_tokenize(str(r).lower())
        hyp_tokens = nltk.word_tokenize(str(h).lower())
        results["meteor"][i] = meteor_score([ref_tokens], hyp_tokens)
    return results

METEOR_PAIR_COLS = {}

for (col_a, col_b) in ANNOTATOR_PAIRS:
    suffix_a = col_a.split("_")[-1]
    suffix_b = col_b.split("_")[-1]
    pair_key = f"{suffix_a}{suffix_b}"
    print(f"Computing METEOR for ann{suffix_a} vs ann{suffix_b} ...")
    meteor_results = meteor_pairwise_batch(
        long_df[col_a].tolist(),
        long_df[col_b].tolist()
    )
    col_name = f"meteor_{pair_key}"
    long_df[col_name] = meteor_results["meteor"]
    METEOR_PAIR_COLS[pair_key] = col_name

print("\n=== Mean Pairwise METEOR by Level ===\n")
meteor_iaa_results = []
for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level]
    row = {"Level": level}
    pair_scores = []
    pair_details = []
    for (col_a, col_b) in ANNOTATOR_PAIRS:
        suffix_a = col_a.split("_")[-1]
        suffix_b = col_b.split("_")[-1]
        pair_key = f"{suffix_a}{suffix_b}"
        col_name = METEOR_PAIR_COLS[pair_key]
        mean_score = sub[col_name].mean(skipna=True)
        n_valid    = sub[col_name].notna().sum()
        pair_scores.append(mean_score)
        pair_details.append(f"ann{suffix_a}-ann{suffix_b}={mean_score:.4f}(n={n_valid})")
        row[f"meteor_ann{suffix_a}_ann{suffix_b}"] = round(mean_score, 4)
    row["meteor_mean"] = round(np.nanmean(pair_scores), 4)
    print(f"  {level} METEOR: "
          f"{' | '.join(pair_details)} | mean={row['meteor_mean']:.4f}")
    meteor_iaa_results.append(row)

meteor_iaa_df = pd.DataFrame(meteor_iaa_results)

print("\n=== METEOR Distribution Summary per Level ===\n")
for level in ["L2", "L3", "L4"]:
    sub = long_df[long_df["level"] == level]
    meteor_cols = [METEOR_PAIR_COLS[f"{a.split('_')[-1]}{b.split('_')[-1]}"]
                   for (a, b) in ANNOTATOR_PAIRS]
    vals = sub[meteor_cols].values.flatten()
    vals = vals[~np.isnan(vals)]
    print(f"  {level} METEOR: min={vals.min():.4f}  "
          f"median={np.median(vals):.4f}  "
          f"max={vals.max():.4f}")
# Out:
# Computing METEOR for ann1 vs ann2 ...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Computing METEOR for ann1 vs ann3 ...
# Computing METEOR for ann2 vs ann3 ...
#
# === Mean Pairwise METEOR by Level ===
#
#   L2 METEOR: ann1-ann2=0.3712(n=49) | ann1-ann3=0.3075(n=49) | ann2-ann3=0.3867(n=49) | mean=0.3551
#   L3 METEOR: ann1-ann2=0.1827(n=24) | ann1-ann3=0.2060(n=24) | ann2-ann3=0.2920(n=45) | mean=0.2269
#   L4 METEOR: ann1-ann2=0.1464(n=49) | ann1-ann3=0.1795(n=49) | ann2-ann3=0.2412(n=49) | mean=0.1890
#
# === METEOR Distribution Summary per Level ===
#
#   L2 METEOR: min=0.0305  median=0.3354  max=0.9906
#   L3 METEOR: min=0.0299  median=0.2318  max=0.5443
#   L4 METEOR: min=0.0303  median=0.1768  max=0.5556

# %%
print("=== Full IAA Metric Comparison (mean across annotator pairs) ===\n")
print(f"{'Level':6} {'BLEU-1':8} {'BLEU-2':8} {'BLEU-4':8} "
      f"{'METEOR':8} {'ROUGE-1':8} {'ROUGE-2':8} {'ROUGE-L':8} {'BERTScore':10}")
print("-" * 78)

for level in ["L2", "L3", "L4"]:
    b  = bleu_iaa_df[bleu_iaa_df["Level"] == level].iloc[0]
    m  = meteor_iaa_df[meteor_iaa_df["Level"] == level].iloc[0]
    r  = rouge_iaa_df[rouge_iaa_df["Level"] == level].iloc[0]
    bs = iaa_df[iaa_df["Level"] == level].iloc[0]
    print(f"{level:6} "
          f"{b['bleu1_mean']:8.4f} "
          f"{b['bleu2_mean']:8.4f} "
          f"{b['bleu4_mean']:8.4f} "
          f"{m['meteor_mean']:8.4f} "
          f"{r['rouge1_mean']:8.4f} "
          f"{r['rouge2_mean']:8.4f} "
          f"{r['rougeL_mean']:8.4f} "
          f"{bs['Mean_F1_overall']:10.4f}")
# Out:
# === Full IAA Metric Comparison (mean across annotator pairs) ===
#
# Level  BLEU-1   BLEU-2   BLEU-4   METEOR   ROUGE-1  ROUGE-2  ROUGE-L  BERTScore
# ------------------------------------------------------------------------------
# L2       0.3712   0.2204   0.0865   0.3551   0.4876   0.2022   0.3910     0.9009
# L3       0.2446   0.1252   0.0422   0.2269   0.2956   0.0725   0.2144     0.8701
# L4       0.2020   0.0691   0.0189   0.1890   0.2530   0.0347   0.1564     0.8647

# %% [markdown]
# ## Sample testing

# %%
# ============================================================
# STANDALONE — Ann1 vs Ann4 evaluation
# Run this independently without needing long_df or prior cells
# ============================================================

import numpy as np
import pandas as pd
import re
import torch
import nltk
from supabase import create_client
from bert_score import score as bert_score
from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('wordnet', quiet=True)

# ============================================================
# Config
# ============================================================
SUPABASE_URL = userdata.get("SUPABASE_URL")
SUPABASE_KEY = userdata.get("SUPABASE_KEY")
DEVICE       = "cuda" if torch.cuda.is_available() else "cpu"
MODEL_TYPE   = "roberta-large"
TARGET_IDS   = [
    "cfe29540-1433-470e-9dc8-612e018bd8b6",
    "dc09d834-178b-48e2-990d-94464475d0fa"
]

print(f"Device: {DEVICE} | Model: {MODEL_TYPE}")

# ============================================================
# Helpers
# ============================================================
NA_PATTERN = re.compile(r"^(not applicable|n/a)$", re.IGNORECASE)

def normalize_value(val):
    if val is None:
        return None
    cleaned = str(val).strip().rstrip(".").strip()
    if cleaned == "" or NA_PATTERN.match(cleaned):
        return None
    return cleaned

def is_missing(text):
    if text is None:
        return True
    cleaned = str(text).strip().rstrip(".").strip()
    return cleaned.lower() in {"not applicable", "n/a", ""}

def parse_charts(text):
    charts = []
    if not text or (isinstance(text, float) and np.isnan(text)):
        return charts
    blocks = re.split(r"(?=Cha[r]?t\s+\d+\s*[:.])", text.strip(), flags=re.IGNORECASE)
    for block in blocks:
        block = block.strip()
        if not block:
            continue
        lines = block.splitlines()
        header = lines[0].strip()
        match = re.match(r"Cha[r]?t\s+(\d+)\s*[:.]\s*(.*)", header, re.IGNORECASE)
        if not match:
            continue
        chart_id = int(match.group(1))
        title    = match.group(2).strip()
        L2 = L3 = L4 = None
        for line in lines[1:]:
            line = line.strip()
            if line.startswith("L2:"):
                L2 = normalize_value(line[3:].strip())
            elif line.startswith("L3:"):
                L3 = normalize_value(line[3:].strip())
            elif line.startswith("L4:"):
                L4 = normalize_value(line[3:].strip())
        charts.append({
            "chart_id": chart_id,
            "title":    title,
            "L2":       L2,
            "L3":       L3,
            "L4":       L4,
        })
    return charts

# ============================================================
# Pull data from Supabase
# ============================================================
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)
response = (
    supabase.table("human_insights")
    .select("*")
    .in_("id", TARGET_IDS)
    .execute()
)
df_raw = pd.DataFrame(response.data)
print(f"\nRows fetched: {len(df_raw)}")
print(f"Columns: {df_raw.columns.tolist()}")

# ============================================================
# Parse ann1 and ann4
# ============================================================
records = []
for _, row in df_raw.iterrows():
    row_id      = row["id"]
    metadata_id = row["metadata_id"]

    parsed_ann1 = {c["chart_id"]: c for c in parse_charts(row["insight_part_1"])}
    parsed_ann4 = {c["chart_id"]: c for c in parse_charts(row["insight_part_4"])}

    all_chart_ids = sorted(set(parsed_ann1.keys()) | set(parsed_ann4.keys()))

    for chart_id in all_chart_ids:
        if chart_id in parsed_ann1:
            title = parsed_ann1[chart_id]["title"]
        elif chart_id in parsed_ann4:
            title = parsed_ann4[chart_id]["title"]
        else:
            title = ""

        for level in ["L2", "L3", "L4"]:
            records.append({
                "row_id":      row_id,
                "metadata_id": metadata_id,
                "chart_id":    chart_id,
                "title":       title,
                "level":       level,
                "unit_id":     f"{row_id}__chart{chart_id}__{level}",
                "annotator_1": parsed_ann1.get(chart_id, {}).get(level),
                "annotator_4": parsed_ann4.get(chart_id, {}).get(level),
            })

df = pd.DataFrame(records)
print(f"\nTotal units parsed: {len(df)}")

# Sanity check
print("\nNone counts per level:")
for level in ["L2", "L3", "L4"]:
    sub = df[df["level"] == level]
    print(f"  {level}: ann1={sub['annotator_1'].isna().sum()} | "
          f"ann4={sub['annotator_4'].isna().sum()} | "
          f"total={len(sub)}")
# Out:
# Device: cuda | Model: roberta-large
#
# Rows fetched: 2
# Columns: ['id', 'metadata_id', 'expected_dataset', 'insight_part_1', 'insight_part_2', 'insight_part_3', 'created_at', 'updated_at', 'updated_at_2', 'updated_at_3', 'irr_flag', 'rejection_reason', 'insight_part_4', 'updated_at_4']
#
# Total units parsed: 39
#
# None counts per level:
#   L2: ann1=0 | ann4=0 | total=13
#   L3: ann1=5 | ann4=4 | total=13
#   L4: ann1=0 | ann4=0 | total=13

# %%
# ============================================================
# Compute ROUGE, BLEU, METEOR
# ============================================================
rouge_sc = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
smoother = SmoothingFunction().method1

ann1_list = df["annotator_1"].tolist()
ann4_list = df["annotator_4"].tolist()

rouge1_scores = np.full(len(df), np.nan)
rouge2_scores = np.full(len(df), np.nan)
rougeL_scores = np.full(len(df), np.nan)
bleu1_scores  = np.full(len(df), np.nan)
bleu2_scores  = np.full(len(df), np.nan)
bleu4_scores  = np.full(len(df), np.nan)
meteor_scores = np.full(len(df), np.nan)

for i, (r, h) in enumerate(zip(ann1_list, ann4_list)):
    if is_missing(r) or is_missing(h):
        continue
    r_str = str(r)
    h_str = str(h)

    scores = rouge_sc.score(r_str, h_str)
    rouge1_scores[i] = scores["rouge1"].fmeasure
    rouge2_scores[i] = scores["rouge2"].fmeasure
    rougeL_scores[i] = scores["rougeL"].fmeasure

    r_tok = nltk.word_tokenize(r_str.lower())
    h_tok = nltk.word_tokenize(h_str.lower())
    bleu1_scores[i] = sentence_bleu([r_tok], h_tok, weights=(1,0,0,0),         smoothing_function=smoother)
    bleu2_scores[i] = sentence_bleu([r_tok], h_tok, weights=(0.5,0.5,0,0),     smoothing_function=smoother)
    bleu4_scores[i] = sentence_bleu([r_tok], h_tok, weights=(0.25,0.25,0.25,0.25), smoothing_function=smoother)
    meteor_scores[i] = meteor_score([r_tok], h_tok)

df["rouge1"] = rouge1_scores
df["rouge2"] = rouge2_scores
df["rougeL"] = rougeL_scores
df["bleu1"]  = bleu1_scores
df["bleu2"]  = bleu2_scores
df["bleu4"]  = bleu4_scores
df["meteor"] = meteor_scores

print("ROUGE / BLEU / METEOR computed.")
# Out:
# ROUGE / BLEU / METEOR computed.

# %%
# ============================================================
# Compute BERTScore
# ============================================================
distances = np.full(len(df), np.nan)
valid_indices = [
    i for i, (r, h) in enumerate(zip(ann1_list, ann4_list))
    if not is_missing(r) and not is_missing(h)
]

if valid_indices:
    valid_refs = [str(ann1_list[i]) for i in valid_indices]
    valid_hyps = [str(ann4_list[i]) for i in valid_indices]
    _, _, F1 = bert_score(
        valid_hyps, valid_refs,
        model_type=MODEL_TYPE,
        device=DEVICE,
        verbose=False
    )
    for idx, f1_val in zip(valid_indices, F1.numpy()):
        distances[idx] = 1.0 - f1_val

df["dist_14"]      = distances
df["F1_ann1_ann4"] = 1.0 - df["dist_14"]

print("BERTScore computed.")
# Out:
# Loading weights:   0%|          | 0/389 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-large
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# BERTScore computed.

# %%
# ============================================================
# Summary — per level + overall
# ============================================================
EVAL_METRICS  = ["rouge1", "rouge2", "rougeL", "bleu1", "bleu2", "bleu4", "meteor", "F1_ann1_ann4"]
METRIC_LABELS = ["ROUGE-1", "ROUGE-2", "ROUGE-L", "BLEU-1", "BLEU-2", "BLEU-4", "METEOR", "BERTScore"]

print("\n=== Ann1 vs Ann4 — Mean Scores by Level ===\n")
header = f"{'Level':6} " + " ".join(f"{l:10}" for l in METRIC_LABELS)
print(header)
print("-" * len(header))

summary_rows = []
for level in ["L2", "L3", "L4", "ALL"]:
    sub = df if level == "ALL" else df[df["level"] == level]
    row = {"Level": level}
    line = f"{level:6} "
    for metric in EVAL_METRICS:
        mean_val = sub[metric].mean(skipna=True)
        n_valid  = sub[metric].notna().sum()
        row[metric] = round(mean_val, 4)
        row[f"{metric}_n"] = n_valid
        line += f"{mean_val:.4f}(n={n_valid}) "
    print(line)
    summary_rows.append(row)

summary_df = pd.DataFrame(summary_rows)

# ============================================================
# Compare against original IAA baseline
# ============================================================
iaa_ref = {
    "L2": {"rougeL": 0.3947, "bleu1": 0.3870, "meteor": 0.3652, "bs": 0.9070},
    "L3": {"rougeL": 0.2073, "bleu1": 0.2541, "meteor": 0.2310, "bs": 0.8749},
    "L4": {"rougeL": 0.1562, "bleu1": 0.2190, "meteor": 0.1978, "bs": 0.8716},
}

print("\n=== Ann1 vs Ann4 vs Original IAA Baseline ===\n")
print(f"{'':25} {'ROUGE-L':10} {'BLEU-1':10} {'METEOR':10} {'BERTScore':10}")
print("-" * 60)

for level in ["L2", "L3", "L4"]:
    sub = df[df["level"] == level]
    rl  = sub["rougeL"].mean(skipna=True)
    b1  = sub["bleu1"].mean(skipna=True)
    met = sub["meteor"].mean(skipna=True)
    bs  = sub["F1_ann1_ann4"].mean(skipna=True)
    ref = iaa_ref[level]

    # Delta vs baseline
    d_rl  = rl  - ref["rougeL"]
    d_b1  = b1  - ref["bleu1"]
    d_met = met - ref["meteor"]
    d_bs  = bs  - ref["bs"]

    print(f"{level} Ann1 vs Ann4:        {rl:.4f}     {b1:.4f}     {met:.4f}     {bs:.4f}")
    print(f"{level} Original IAA mean:   {ref['rougeL']:.4f}     {ref['bleu1']:.4f}     {ref['meteor']:.4f}     {ref['bs']:.4f}")
    print(f"{level} Delta (Ann4 - IAA):  {d_rl:+.4f}     {d_b1:+.4f}     {d_met:+.4f}     {d_bs:+.4f}")
    print()

# ============================================================
# Per-unit qualitative inspection
# ============================================================
print("\n=== Per-unit Detail ===\n")
for _, row in df.iterrows():
    print(f"unit  : {row['unit_id']}")
    print(f"level : {row['level']}  |  chart: {row['chart_id']} — {row['title']}")
    print(f"scores: ROUGE-L={row['rougeL']:.4f}  BLEU-1={row['bleu1']:.4f}  "
          f"METEOR={row['meteor']:.4f}  BERTScore={row['F1_ann1_ann4']:.4f}")
    print(f"ann1  : {row['annotator_1']}")
    print(f"ann4  : {row['annotator_4']}")
    print()

# ============================================================
# Export
# ============================================================
with pd.ExcelWriter("iaa_ann4_evaluation.xlsx") as writer:
    summary_df.to_excel(writer, sheet_name="Summary_by_Level", index=False)
    df.to_excel(writer,         sheet_name="Per_Unit_Detail",  index=False)

print("Saved: iaa_ann4_evaluation.xlsx")
# Out:
# === Ann1 vs Ann4 — Mean Scores by Level ===
#
# Level  ROUGE-1    ROUGE-2    ROUGE-L    BLEU-1     BLEU-2     BLEU-4     METEOR     BERTScore
# ----------------------------------------------------------------------------------------------
# L2     0.4762(n=13) 0.1966(n=13) 0.3872(n=13) 0.3659(n=13) 0.2090(n=13) 0.0893(n=13) 0.3534(n=13) 0.9140(n=13)
# L3     0.2928(n=8) 0.0363(n=8) 0.2044(n=8) 0.2616(n=8) 0.0892(n=8) 0.0214(n=8) 0.1956(n=8) 0.8828(n=8)
# L4     0.2689(n=13) 0.0445(n=13) 0.1838(n=13) 0.2251(n=13) 0.0957(n=13) 0.0164(n=13) 0.1980(n=13) 0.8670(n=13)
# ALL    0.3538(n=34) 0.1008(n=34) 0.2664(n=34) 0.2875(n=34) 0.1375(n=34) 0.0455(n=34) 0.2569(n=34) 0.8887(n=34)
#
# === Ann1 vs Ann4 vs Original IAA Baseline ===
#
#                           ROUGE-L    BLEU-1     METEOR     BERTScore
# ------------------------------------------------------------
# L2 Ann1 vs Ann4:        0.3872     0.3659     0.3534     0.9140
# L2 Original IAA mean:   0.3947     0.3870     0.3652     0.9070
# L2 Delta (Ann4 - IAA):  -0.0075     -0.0211     -0.0118     +0.0070
#
# L3 Ann1 vs Ann4:        0.2044     0.2616     0.1956     0.8828
# L3 Original IAA mean:   0.2073     0.2541     0.2310     0.8749
# L3 Delta (Ann4 - IAA):  -0.0029     +0.0075     -0.0354     +0.0079
#
# L4 Ann1 vs Ann4:        0.1838     0.2251     0.1980     0.8670
# L4 Original IAA mean:   0.1562     0.2190     0.1978     0.8716
# L4 Delta (Ann4 - IAA):  +0.0276     +0.0061     +0.0002     -0.0046
#
#
# === Per-unit Detail ===
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart1__L2
# level : L2  |  chart: 1 — Segment Summary
# scores: ROUGE-L=0.2800  BLEU-1=0.3333  METEOR=0.2403  BERTScore=0.9095
# ann1  : The highest orders are contributed by the consumer segment at 2,586 orders, while the lowest is the home office segment at 909 orders
# ann4  : The largest share of sales is consumer, with sales of 2,586, followed by corporate and home office with sales of 1,514 and 909, respectively
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart1__L3
# level : L3  |  chart: 1 — Segment Summary
# scores: ROUGE-L=nan  BLEU-1=nan  METEOR=nan  BERTScore=nan
# ann1  : None
# ann4  : None
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart1__L4
# level : L4  |  chart: 1 — Segment Summary
# scores: ROUGE-L=0.1918  BLEU-1=0.3333  METEOR=0.3255  BERTScore=0.8517
# ann1  : This segmentation contribution is healthy, where the consumer takes all the higher order quantity, followed by the corporate level, and the lowest of the home office, which would take only a small quantity of orders
# ann4  : Consumer, being the largest segment of sales, although it doesn't specify the amount of sales from this segment, could reflect the types of orders that was made, which are personally used stationery such as binders and paper
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart2__L2
# level : L2  |  chart: 2 — Region Summary
# scores: ROUGE-L=0.4561  BLEU-1=0.5806  METEOR=0.3461  BERTScore=0.9302
# ann1  : The west region is dominating the sales at 1,611 orders, followed by the East at 1,401 orders, the Central at 1,175, and the South with 822 orders
# ann4  : Most sales are made in the west and east regions, with 1,611 and 1,401, respectively, followed by central region (1,175) and south region (822)
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart2__L3
# level : L3  |  chart: 2 — Region Summary
# scores: ROUGE-L=nan  BLEU-1=nan  METEOR=nan  BERTScore=nan
# ann1  : None
# ann4  : None
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart2__L4
# level : L4  |  chart: 2 — Region Summary
# scores: ROUGE-L=0.1481  BLEU-1=0.1259  METEOR=0.0987  BERTScore=0.8536
# ann1  : The dominance of the West region indicates the higher population in the US state of California, while the East is condensed with many populated states, cumulating the total orders
# ann4  : West and East regions have a smaller sales gap compared to the other two regions may indicate uneven sales promotion or effort in different regions
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart3__L2
# level : L2  |  chart: 3 — Customers by # Orders Placed Summary
# scores: ROUGE-L=0.4118  BLEU-1=0.3436  METEOR=0.3216  BERTScore=0.9156
# ann1  : There are 134 customers who each placed 5 orders in a year, followed by 116 customers who each placed 7 orders
# ann4  : Most customers (134) placed 5 orders, while only 1 customer placed 17 orders
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart3__L3
# level : L3  |  chart: 3 — Customers by # Orders Placed Summary
# scores: ROUGE-L=0.1500  BLEU-1=0.1905  METEOR=0.1190  BERTScore=0.8497
# ann1  : This pattern may suggest a normal distribution with slight right skew, suggesting customers may have repeated orders throughout the year
# ann4  : Most customers ordered 5 to 7 times, with a larger share of customers ordering fewer than 8 times than more
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart3__L4
# level : L4  |  chart: 3 — Customers by # Orders Placed Summary
# scores: ROUGE-L=0.1739  BLEU-1=0.2432  METEOR=0.1486  BERTScore=0.8718
# ann1  : The highest orders were in the range of 4 to 9 orders, reflecting the customers' loyalty, while the other should be analyzed using analytical tools to support targeting for campaign planning or bundling strategy
# ann4  : With more customers having repeat orders instead of a single order, this indicates that the level of satisfaction is quite good, although more effort might be needed to increase the number of highly loyal customers
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart4__L2
# level : L2  |  chart: 4 — Ship Mode Summary
# scores: ROUGE-L=0.2667  BLEU-1=0.3103  METEOR=0.3800  BERTScore=0.8850
# ann1  : The highest shipping method is using standard class at 2,994 orders, while the lowest is the same day at 264
# ann4  : 2,994 orders used standard class shipping, followed by second class, first class, and same day shipping with 964, 787, and 264 orders, respectively
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart4__L3
# level : L3  |  chart: 4 — Ship Mode Summary
# scores: ROUGE-L=nan  BLEU-1=nan  METEOR=nan  BERTScore=nan
# ann1  : None
# ann4  : None
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart4__L4
# level : L4  |  chart: 4 — Ship Mode Summary
# scores: ROUGE-L=0.1667  BLEU-1=0.1176  METEOR=0.1989  BERTScore=0.8714
# ann1  : This distribution of shipping mode is normal, where people prefer cheaper delivery over faster shipping times
# ann4  : Most customers chose the standard class, followed by second class shipping mode, likely due to customers preferring the lower shipping cost offered by the standard class without putting much urgency on speed
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart5__L2
# level : L2  |  chart: 5 — Monthly Orders Details
# scores: ROUGE-L=0.4444  BLEU-1=0.3529  METEOR=0.3676  BERTScore=0.9166
# ann1  : The highest orders occurred in November 2019 at around 250 orders
# ann4  : The highest number of orders was in November 2019, and the lowest was in January 2017
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart5__L3
# level : L3  |  chart: 5 — Monthly Orders Details
# scores: ROUGE-L=0.2540  BLEU-1=0.3025  METEOR=0.2164  BERTScore=0.8875
# ann1  : The yearly trend over four years shows that the orders are increasing each year, while the monthly trends suggest the same patterns in each year, where orders are surging starting from September throughout the end of the year
# ann4  : The number of orders tends to increase over the years, and fluctuates over the months (throughout the year) with sudden spikes in September and November
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart5__L4
# level : L4  |  chart: 5 — Monthly Orders Details
# scores: ROUGE-L=0.1429  BLEU-1=0.1429  METEOR=0.2383  BERTScore=0.8639
# ann1  : The yearly increase may suggest inflation, while the monthly trend is always increasing from September, suggesting holiday season demands
# ann4  : The number of orders always starts low at the beginning of the year and spikes in September, likely due to the start of academic year, before dipping in October, and increases again in November, likely due to the holiday season, which requires more strategy to even out orders in earlier months
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart6__L2
# level : L2  |  chart: 6 — Orders by Sub Category Details
# scores: ROUGE-L=0.5106  BLEU-1=0.4800  METEOR=0.4955  BERTScore=0.9403
# ann1  : Binders have the highest orders at 1,316, followed by papers at 1,191, with the lowest being Copiers at 68
# ann4  : The most ordered category is binders with 1,316 orders followed by paper with 1,191 orders, and the least ordered is copiers with 68 orders
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart6__L3
# level : L3  |  chart: 6 — Orders by Sub Category Details
# scores: ROUGE-L=nan  BLEU-1=nan  METEOR=nan  BERTScore=nan
# ann1  : None
# ann4  : None
#
# unit  : dc09d834-178b-48e2-990d-94464475d0fa__chart6__L4
# level : L4  |  chart: 6 — Orders by Sub Category Details
# scores: ROUGE-L=0.1395  BLEU-1=0.0833  METEOR=0.1404  BERTScore=0.8609
# ann1  : These two highest-order placements suggest high sales volume due to low per-unit price, with patterns similar to those of other sub-categories of office supplies
# ann4  : Most orders are likely low-priced office supply items like binders and paper, which suggests that these are the items that customers frequently need and therefore the company might need to offer more selection of these items while also investing in efforts for more high-margin items, especially for corporate and home office segments, such as machines and furnitures
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart1__L2
# level : L2  |  chart: 1 — Scoreboard Overview
# scores: ROUGE-L=0.3333  BLEU-1=0.0398  METEOR=0.1081  BERTScore=0.9063
# ann1  : Sales are about $733.2K, profit is $93.4K, orders are 1,687, and quantity is 12,476 units
# ann4  : Total sales are $733.2K
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart1__L3
# level : L3  |  chart: 1 — Scoreboard Overview
# scores: ROUGE-L=0.2400  BLEU-1=0.2815  METEOR=0.1562  BERTScore=0.8978
# ann1  : Overall, the trend shows an increase in sales, orders, and quantity towards the end of the year, while profit is highest early in the year and increases steadily afterward
# ann4  : Overall, the sales pattern appears to increase from the beginning to the end, although there are some fluctuations over the period
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart1__L4
# level : L4  |  chart: 1 — Scoreboard Overview
# scores: ROUGE-L=0.1786  BLEU-1=0.1935  METEOR=0.1460  BERTScore=0.8772
# ann1  : The lower profit rate at the end of the year may suggest a promotional strategy where sales depend on the discounted price, so the profit margin is small
# ann4  : Increasing sales trend throughout the year, and seems to peak in November, likely due to holiday sales, might suggest a certain demand pattern and or uneven sales effort
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart2__L2
# level : L2  |  chart: 2 — Sales Target
# scores: ROUGE-L=0.1905  BLEU-1=0.0544  METEOR=0.0949  BERTScore=0.9060
# ann1  : With total sales of $733.2K, which is still less than the target of $1.0M
# ann4  : Total profit is $93.4K
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart2__L3
# level : L3  |  chart: 2 — Sales Target
# scores: ROUGE-L=nan  BLEU-1=nan  METEOR=nan  BERTScore=nan
# ann1  : None
# ann4  : Profit fluctuates over the months, peaking in what appears to be the first quarter, before dipping, slightly increasing, and then plateauing until the end of the year
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart2__L4
# level : L4  |  chart: 2 — Sales Target
# scores: ROUGE-L=0.1408  BLEU-1=0.2500  METEOR=0.1886  BERTScore=0.8680
# ann1  : The sales target is not achieved, maybe due to relying on the end-of-year sales alone, suggesting the need to employ a different sales strategy to ensure steady sales across the year
# ann4  : Fluctuating profit in the year 2022 seems different from the previous year, and doesn't seem to align with the total sales made in respective months, suggesting there might be fluctuation in operational cost or price of goods
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart3__L2
# level : L2  |  chart: 3 — Monthly Target
# scores: ROUGE-L=0.5600  BLEU-1=0.4811  METEOR=0.5842  BERTScore=0.9513
# ann1  : Out of the monthly sales, only in November could the sales surpass their target of $100K
# ann4  : In November, sales surpassed the monthly target of $100K
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart3__L3
# level : L3  |  chart: 3 — Monthly Target
# scores: ROUGE-L=0.1455  BLEU-1=0.3224  METEOR=0.1618  BERTScore=0.8808
# ann1  : Overall, early-year sales are underperforming, while in September, we see an uptrend through the end of the year, but we are not able to achieve the target
# ann4  : Except for November, in no other months the company surpass the monthly sales target, and although the overall sales trend is increasing, it fluctuates over the months
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart3__L4
# level : L4  |  chart: 3 — Monthly Target
# scores: ROUGE-L=0.2857  BLEU-1=0.2727  METEOR=0.3206  BERTScore=0.8711
# ann1  : The sales target is not achieved due to having the same target each month of $100K, suggesting the need for a different approach to making a realistic target
# ann4  : With November being the only month to reach sales target (likely due to seasonal discount event), this indicates 2 things: the company set an unrealistic target or the sales effort is not good enough except for November, therefore, there needs to be a strategy to improve these two things
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart4__L2
# level : L2  |  chart: 4 — Sales by State
# scores: ROUGE-L=0.5000  BLEU-1=0.6064  METEOR=0.6148  BERTScore=0.9292
# ann1  : California leads the sales by $146,4K, while New York, Washington, Texas, and Pennsylvania follow with progressively smaller yet still substantial figures
# ann4  : The highest sales were made in California with $146.4K, followed by New York, Washington, Texas, and Pennsylvania
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart4__L3
# level : L3  |  chart: 4 — Sales by State
# scores: ROUGE-L=0.1951  BLEU-1=0.2727  METEOR=0.1938  BERTScore=0.8912
# ann1  : A small group of states contributes a disproportionate share of total sales, with coastal and large‑population states dominating the top five
# ann4  : Overall, the highest sales were made in coastal states, mostly on the West Coast, with California being the exception
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart4__L4
# level : L4  |  chart: 4 — Sales by State
# scores: ROUGE-L=0.2381  BLEU-1=0.2727  METEOR=0.2273  BERTScore=0.8731
# ann1  : This geographic condition suggests that a different expansion into mid-tier states than the coastal areas could be the next growth target
# ann4  : This suggests that the difference in demand was driven by different economic conditions, demography, or consumer taste in different states
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart5__L2
# level : L2  |  chart: 5 — Sales by Sub-Category
# scores: ROUGE-L=0.1905  BLEU-1=0.2143  METEOR=0.1579  BERTScore=0.8779
# ann1  : Phones led the sub-categories in sales at $105K
# ann4  : The largest sales were phones, dominating 14% of total sales this year
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart5__L3
# level : L3  |  chart: 5 — Sales by Sub-Category
# scores: ROUGE-L=0.1778  BLEU-1=0.1653  METEOR=0.1060  BERTScore=0.8795
# ann1  : While all sub-categories' sales surpassed the previous year's sales, Tables' sales remain the same as the previous year with no increase (0%)
# ann4  : Across the shown categories, sales this year exceeded last year, suggesting that top-performing products continue to be highly sought after
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart5__L4
# level : L4  |  chart: 5 — Sales by Sub-Category
# scores: ROUGE-L=0.2143  BLEU-1=0.2879  METEOR=0.1586  BERTScore=0.8674
# ann1  : We can see from this year's sales that the phone is the product with the best sales performance, while last year Chairs were expected to be the best, but this year their performance has dropped to rank two, suggesting different customer needs this year
# ann4  : The top 5 products made up more than half of the sales and all exceeded last year's sales, indicating that these products have high competitiveness in the market, and effort should be made to maintain or improve this
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart6__L2
# level : L2  |  chart: 6 — Sales
# scores: ROUGE-L=0.4800  BLEU-1=0.5367  METEOR=0.4920  BERTScore=0.9209
# ann1  : Current year sales of $733,215 surpassing 20.4% of the previous year
# ann4  : Sales this year increased by 20.4% compared to the previous year
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart6__L3
# level : L3  |  chart: 6 — Sales
# scores: ROUGE-L=0.2000  BLEU-1=0.2849  METEOR=0.1439  BERTScore=0.8885
# ann1  : The monthly trend shows that early-year sales have lower performance compared to the previous year, while after June, the sales are higher than the previous year
# ann4  : This year's fluctuating sales reflect those of last year, although sales in February, April, and May this year were lower than last
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart6__L4
# level : L4  |  chart: 6 — Sales
# scores: ROUGE-L=0.1967  BLEU-1=0.4000  METEOR=0.2477  BERTScore=0.8834
# ann1  : This suggests an increase in sales performance toward the end of the year, while still needing evaluation in the early year months, such as February, April, and May
# ann4  : Low sales in February and April, despite the low sales in the same months last year, indicate a persistent seasonal problem in sales that needs to be addressed to increase the overall sales
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart7__L2
# level : L2  |  chart: 7 — Sales by Segments
# scores: ROUGE-L=0.4091  BLEU-1=0.4232  METEOR=0.3916  BERTScore=0.8935
# ann1  : The consumer segment has the highest sales at $332K, followed by Corporate and Home Office, where all segments successfully surpassed their previous year's sales
# ann4  : Consumer segment accounted for 45% of total sales, followed by corporate and home office at 33% and 22%, respectively
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart7__L3
# level : L3  |  chart: 7 — Sales by Segments
# scores: ROUGE-L=0.2727  BLEU-1=0.2727  METEOR=0.4679  BERTScore=0.8873
# ann1  : The trend also shows an increase in sales toward the end of the year
# ann4  : Overall, sales by every segment surpassed those of last year and there was an increase in trend sales over the months, although for the Consumer segment, there were more fluctuations
#
# unit  : cfe29540-1433-470e-9dc8-612e018bd8b6__chart7__L4
# level : L4  |  chart: 7 — Sales by Segments
# scores: ROUGE-L=0.1728  BLEU-1=0.2036  METEOR=0.1349  BERTScore=0.8568
# ann1  : However, as we can see more clearly, the consumer was having successful sales in November and December, while both Corporate and Home Office saw their sales drop in December, suggesting a combination of seasonal business slowdowns, employee vacations, and strategic financial decisions
# ann4  : The larger share of the consumer segment implies that the company might be relying more on smaller sales, and therefore should consider strategy in attracting loyal corporate customers with higher amount of order to ensure long-term business growth
#
# Saved: iaa_ann4_evaluation.xlsx

# %%
# ============================================================
# Summary comparison — ann1 vs ann2, ann1 vs ann3, ann1 vs ann4
# Two dashboards only: cfe29540 and e743f36f
# ============================================================

TARGET_IDS = [
    "cfe29540-1433-470e-9dc8-612e018bd8b6",
    "dc09d834-178b-48e2-990d-94464475d0fa"
]

# Filter long_df to the two target dashboards
sub_long = long_df[long_df["row_id"].isin(TARGET_IDS)].copy()
print(f"Units in target dashboards: {len(sub_long)}")

# Pairs to compare — all vs ann1
PAIRS = {
    "Ann1 vs Ann2": ("annotator_1", "annotator_2", "F1_ann1_ann2", "rouge_rouge1_12", "rouge_rouge2_12", "rouge_rougeL_12", "bleu_bleu1_12", "bleu_bleu2_12", "bleu_bleu4_12", "meteor_12"),
    "Ann1 vs Ann3": ("annotator_1", "annotator_3", "F1_ann1_ann3", "rouge_rouge1_13", "rouge_rouge2_13", "rouge_rougeL_13", "bleu_bleu1_13", "bleu_bleu2_13", "bleu_bleu4_13", "meteor_13"),
}

METRIC_LABELS = ["ROUGE-1", "ROUGE-2", "ROUGE-L", "BLEU-1", "BLEU-2", "BLEU-4", "METEOR", "BERTScore"]

# ============================================================
# Compute ann1 vs ann4 scores on the two dashboards
# (reuse df from previous cells)
# ============================================================
ann4_rouge1  = df["rouge1"].values
ann4_rouge2  = df["rouge2"].values
ann4_rougeL  = df["rougeL"].values
ann4_bleu1   = df["bleu1"].values
ann4_bleu2   = df["bleu2"].values
ann4_bleu4   = df["bleu4"].values
ann4_meteor  = df["meteor"].values
ann4_bs      = df["F1_ann1_ann4"].values

# ============================================================
# Print summary table per level
# ============================================================
print("\n=== Ann1 vs Ann2 / Ann3 / Ann4 — Mean Scores by Level ===")
print(f"(Filtered to dashboards: cfe29540 and e743f36f)\n")

for level in ["L2", "L3", "L4", "ALL"]:
    sub2 = sub_long if level == "ALL" else sub_long[sub_long["level"] == level]
    sub4 = df if level == "ALL" else df[df["level"] == level]

    print(f"--- {level} ---")
    print(f"{'Pair':15} {'ROUGE-1':9} {'ROUGE-2':9} {'ROUGE-L':9} "
          f"{'BLEU-1':9} {'BLEU-2':9} {'BLEU-4':9} {'METEOR':9} {'BERTScore':10}")
    print("-" * 90)

    # Ann1 vs Ann2
    print(f"{'Ann1 vs Ann2':15} "
          f"{sub2['rouge_rouge1_12'].mean(skipna=True):.4f}    "
          f"{sub2['rouge_rouge2_12'].mean(skipna=True):.4f}    "
          f"{sub2['rouge_rougeL_12'].mean(skipna=True):.4f}    "
          f"{sub2['bleu_bleu1_12'].mean(skipna=True):.4f}    "
          f"{sub2['bleu_bleu2_12'].mean(skipna=True):.4f}    "
          f"{sub2['bleu_bleu4_12'].mean(skipna=True):.4f}    "
          f"{sub2['meteor_12'].mean(skipna=True):.4f}    "
          f"{sub2['F1_ann1_ann2'].mean(skipna=True):.4f}")

    # Ann1 vs Ann3
    print(f"{'Ann1 vs Ann3':15} "
          f"{sub2['rouge_rouge1_13'].mean(skipna=True):.4f}    "
          f"{sub2['rouge_rouge2_13'].mean(skipna=True):.4f}    "
          f"{sub2['rouge_rougeL_13'].mean(skipna=True):.4f}    "
          f"{sub2['bleu_bleu1_13'].mean(skipna=True):.4f}    "
          f"{sub2['bleu_bleu2_13'].mean(skipna=True):.4f}    "
          f"{sub2['bleu_bleu4_13'].mean(skipna=True):.4f}    "
          f"{sub2['meteor_13'].mean(skipna=True):.4f}    "
          f"{sub2['F1_ann1_ann3'].mean(skipna=True):.4f}")

    # Ann1 vs Ann4
    print(f"{'Ann1 vs Ann4':15} "
          f"{sub4['rouge1'].mean(skipna=True):.4f}    "
          f"{sub4['rouge2'].mean(skipna=True):.4f}    "
          f"{sub4['rougeL'].mean(skipna=True):.4f}    "
          f"{sub4['bleu1'].mean(skipna=True):.4f}    "
          f"{sub4['bleu2'].mean(skipna=True):.4f}    "
          f"{sub4['bleu4'].mean(skipna=True):.4f}    "
          f"{sub4['meteor'].mean(skipna=True):.4f}    "
          f"{sub4['F1_ann1_ann4'].mean(skipna=True):.4f}")
    print()
# Out:
# Units in target dashboards: 39
#
# === Ann1 vs Ann2 / Ann3 / Ann4 — Mean Scores by Level ===
# (Filtered to dashboards: cfe29540 and e743f36f)
#
# --- L2 ---
# Pair            ROUGE-1   ROUGE-2   ROUGE-L   BLEU-1    BLEU-2    BLEU-4    METEOR    BERTScore
# ------------------------------------------------------------------------------------------
# Ann1 vs Ann2    0.4962    0.2024    0.4102    0.3800    0.2311    0.0799    0.3950    0.9034
# Ann1 vs Ann3    0.4533    0.1652    0.3857    0.3328    0.1838    0.0598    0.3051    0.9035
# Ann1 vs Ann4    0.4762    0.1966    0.3872    0.3659    0.2090    0.0893    0.3534    0.9140
#
# --- L3 ---
# Pair            ROUGE-1   ROUGE-2   ROUGE-L   BLEU-1    BLEU-2    BLEU-4    METEOR    BERTScore
# ------------------------------------------------------------------------------------------
# Ann1 vs Ann2    0.2526    0.0525    0.1855    0.1740    0.0701    0.0291    0.1470    0.8702
# Ann1 vs Ann3    0.2376    0.0692    0.1837    0.2039    0.1112    0.0516    0.1769    0.8695
# Ann1 vs Ann4    0.2928    0.0363    0.2044    0.2616    0.0892    0.0214    0.1956    0.8828
#
# --- L4 ---
# Pair            ROUGE-1   ROUGE-2   ROUGE-L   BLEU-1    BLEU-2    BLEU-4    METEOR    BERTScore
# ------------------------------------------------------------------------------------------
# Ann1 vs Ann2    0.2175    0.0200    0.1399    0.1650    0.0431    0.0106    0.1221    0.8632
# Ann1 vs Ann3    0.1972    0.0126    0.1288    0.1692    0.0387    0.0110    0.1378    0.8590
# Ann1 vs Ann4    0.2689    0.0445    0.1838    0.2251    0.0957    0.0164    0.1980    0.8670
#
# --- ALL ---
# Pair            ROUGE-1   ROUGE-2   ROUGE-L   BLEU-1    BLEU-2    BLEU-4    METEOR    BERTScore
# ------------------------------------------------------------------------------------------
# Ann1 vs Ann2    0.3323    0.0974    0.2539    0.2493    0.1214    0.0415    0.2323    0.8802
# Ann1 vs Ann3    0.3046    0.0843    0.2400    0.2399    0.1112    0.0392    0.2110    0.8785
# Ann1 vs Ann4    0.3538    0.1008    0.2664    0.2875    0.1375    0.0455    0.2569    0.8887
